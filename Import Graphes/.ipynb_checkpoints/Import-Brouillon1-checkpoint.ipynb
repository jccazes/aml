# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("transactions_01160000_01169999.csv",sep=',')

# %%
data.head()
# Out:
#                                                 hash  nonce  \
# 0  0xba048f59c055470fed2668d2d040879ab5ef5dfc106c...     42
# 1  0x0a1807644cef7ea7eca30c075512b1136c28b24ac538...  37665
# 2  0x4d1ebaeddfdf5db17a83753003f6eaa50841b599ef15...  37666
# 3  0xac1baec5b7ce60fa5b7afcb1f362e41c5cb529384e69...     14
# 4  0xda255e01a213a47f3454e085681198f48b61ea947ab4...    138
#
#                                           block_hash  block_number  \
# 0  0xcb16bbb2b7b593f506369f0174355254485960fba2cd...       1160100
# 1  0x62ee818f0b2b3047bd725317e820d83f0f5c5b9971b1...       1160101
# 2  0x62ee818f0b2b3047bd725317e820d83f0f5c5b9971b1...       1160101
# 3  0x40fc1e112e67eb5ad1cef2517dcce281fd43d18349d9...       1160104
# 4  0x40fc1e112e67eb5ad1cef2517dcce281fd43d18349d9...       1160104
#
#    transaction_index                                from_address  \
# 0                  0  0xc5698e5ed169e2ff546455c0431543bc641fdb20
# 1                  0  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 2                  1  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 3                  0  0x1431354497e6e11e24ec3fe9a76d4f7897e2a712
# 4                  1  0x4eb44a2d45370a8fe762040447112a6ce42ca6a2
#
#                                    to_address                value     gas  \
# 0  0x1699333a4e46093e15a94b4a213b88eb8a963834   111955450000000000   21000
# 1  0x9af09991ad63814e53ffc1bccf213ee74027608b                    1  300000
# 2  0x9af09991ad63814e53ffc1bccf213ee74027608b                    1  300000
# 3  0x32be343b94f860124dc4fee278fdcbd38c102d88  9999370000000000000   21000
# 4  0x32be343b94f860124dc4fee278fdcbd38c102d88  7023716000000000000   21000
#
#      gas_price                                              input
# 0  50000000000                                                 0x
# 1  52000000000  0x3ed4867900000000000000000000000036c425e72bbc...
# 2  52000000000  0x3ed48679000000000000000000000000490c0dd13bfe...
# 3  30000000000                                                 0x
# 4  30000000000                                                 0x

# %%
print(len(data['from_address'].unique()))
print(len(data['to_address'].unique()))
# Out:
# 6618
# 11960

# %%
data.dtypes
# Out:
# hash                 object
# nonce                 int64
# block_hash           object
# block_number          int64
# transaction_index     int64
# from_address         object
# to_address           object
# value                object
# gas                   int64
# gas_price             int64
# input                object
# dtype: object

# %%
# On transforme les addresses en str pour éviter les ennuis

data[['from_address', 'to_address']] = data[['from_address', 'to_address']].astype(str)

# %%
# Vérifications

c = 0
for add in data['from_address'].values:
    if type(add) != str:
        c += 1
        
cdef parallel_outlier(graph,coeff_lambda):
    """
    Prend en arguments le graphe de transactions à étudier, et lambda permettant d'ajuster le seuil 
    Renvoie les outliers au sens des transactions parallèles 
    sous forme d'un DF pandas 
    
    """
# Out:
#   File "<ipython-input-7-7998f53a6c7e>", line 8
#     cdef parallel_outlier(graph,coeff_lambda):
#                         ^
# SyntaxError: invalid syntax

# %%
# Vérifications

c = 0
for add in data['to_address'].values:
    if type(add) != str:
        c += 1
        
c
# Out:
# 0

# %%
full_addresses = np.append(data['from_address'].values,data['to_address'].values)
full_addresses
# Out:
# array(['0xc5698e5ed169e2ff546455c0431543bc641fdb20',
#        '0xc400b9d93a23b0be5d41ab337ad605988aef8463',
#        '0xc400b9d93a23b0be5d41ab337ad605988aef8463', ...,
#        '0x32be343b94f860124dc4fee278fdcbd38c102d88',
#        '0x32be343b94f860124dc4fee278fdcbd38c102d88',
#        '0x32be343b94f860124dc4fee278fdcbd38c102d88'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

Encoder = LabelEncoder()
Encoder.fit(full_addresses) #Apprend sur les addresses 

new_from = Encoder.transform(data['from_address']) # On transforme
new_to = Encoder.transform(data['to_address'])     # On transforme

# %%
data['from_address'] = new_from
data['to_address'] = new_to

# %%
# On transforme la colonne value en float
data[['value']] = data[['value']].astype(float)

# %%
# On utilise le tableau partiel avec les addresses et les montants transférés
data2 = data[['from_address','to_address','value']]

# %%
data2.head()
# Out:
#    from_address  to_address         value
# 0          9959        1235  1.119554e+17
# 1          9883        7823  1.000000e+00
# 2          9883        7823  1.000000e+00
# 3          1125        2638  9.999370e+18
# 4          4036        2638  7.023716e+18

# %%
# On somme les transactions entre meme personnes 
df = data2.groupby(['from_address','to_address']).sum()

# %%
def Missing_values(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total,percent], axis=1, keys=['Total', 'Pourcentage'])
    #Affiche que les variables avec des na
    print (missing_data[(percent>0)],'\n' )

# %%
Missing_values(data2)
Missing_values(df)
# Out:
# Empty DataFrame
# Columns: [Total, Pourcentage]
# Index: []
#
# Empty DataFrame
# Columns: [Total, Pourcentage]
# Index: []

# %%
# a rajouter, une colonne avec les balances en vertice property

# %%
df
# Out:
#                                 value
# from_address to_address
# 0            1012        1.664428e+20
# 2            3959        5.000000e+18
# 3            2140        5.000000e+17
# 5            10359       1.100000e+18
# 7            2282        9.400000e+19
#              3058        3.200000e+19
#              3603        9.360000e+19
#              3841        9.500000e+19
#              5072        9.500000e+19
#              8103        9.500000e+19
#              10317       9.500000e+19
#              12707       9.400000e+19
# 12           2638        2.241353e+19
# 13           8215        1.500000e+19
# 17           2978        5.000000e+17
# 25           5917        2.000000e+18
#              11950       2.000000e+18
# 27           188         1.000000e+18
# 29           7549        3.000000e+18
# 31           5896        5.957200e+17
# 36           5893        4.010000e+18
# 37           1914        7.705119e+18
#              6042        1.500000e+19
# 39           2638        8.933700e+18
# 41           2638        7.199370e+18
# 43           2638        3.404078e+19
# 48           2846        1.200000e+18
# 49           2638        1.046544e+18
# 50           1012        3.038620e+17
# 56           47          1.000000e+18
# ...                               ...
# 12817        2888        5.000000e+17
# 12818        2638        4.327499e+19
# 12819        6683        2.100000e+18
# 12820        12659       8.438417e+18
# 12821        2638        2.095443e+18
# 12824        2638        2.241018e+19
# 12827        5761        1.384273e+22
# 12828        2638        4.648744e+18
# 12829        9521        1.423900e+18
# 12831        2638        1.299370e+18
# 12833        2638        8.671404e+18
# 12836        2638        1.389370e+18
# 12838        7663        2.500000e+19
#              8465        4.500000e+20
#              12312       5.000000e+20
# 12839        2638        2.260614e+18
# 12841        5761        3.495000e+16
# 12842        2638        1.089943e+18
# 12844        2638        1.039370e+18
# 12848        1012        7.499958e+19
# 12849        2904        1.000000e+18
# 12852        3529        2.000000e+18
# 12853        11885       2.000000e+18
# 12854        6763        2.500000e+21
#              7655        1.000000e+18
# 12856        2723        1.150000e+20
# 12857        7144        8.100000e+19
# 12858        2638        5.779994e+20
# 12859        2638        2.870797e+20
# 12860        1012        7.169777e+19
#
# [18915 rows x 1 columns]

# %% [markdown]
# # Import sous GraphTool

# %%
from graph_tool.all import *

# %%
# Création du graphe vide
g = Graph(directed=True) 

# Ajout des arêtes suivant le np.array
vmap = g.add_edge_list(data2[['from_address','to_address']].values)

# Ajout des edge weights 
ew = g.new_edge_property("double")
ew.a = data2['value'].values
g.ep['edge_weight'] = ew

# %%
data2
# Out:
#        from_address  to_address         value
# 0              9959        1235  1.119554e+17
# 1              9883        7823  1.000000e+00
# 2              9883        7823  1.000000e+00
# 3              1125        2638  9.999370e+18
# 4              4036        2638  7.023716e+18
# 5              1183        2638  4.955182e+18
# 6              2638        2299  4.093302e+19
# 7              1196        2638  1.386536e+18
# 8              2638        2339  1.999422e+18
# 9              2727        2638  4.949370e+18
# 10             2638        1771  9.900000e+17
# 11             1156        2638  1.419370e+18
# 12             2638        5298  1.799990e+21
# 13             6641        2638  4.976694e+18
# 14             2638        7345  7.754446e+18
# 15             2638        8944  3.996077e+18
# 16             8979        7177  6.231003e+17
# 17             1584        6690  1.020709e+18
# 18             1648       12659  2.804224e+18
# 19             9883        7823  1.000000e+00
# 20             3888        7778  4.950000e+18
# 21             1664        7823  1.000000e+00
# 22             3505        8948  1.000000e+17
# 23             9883        7823  1.000000e+00
# 24            10123        9480  9.871668e+18
# 25            10123        4163  9.871668e+16
# 26             5387        1474  1.000000e+18
# 27             1664        7823  1.000000e+00
# 28             9883        7823  1.000000e+00
# 29            11805        2303  1.610550e+15
# ...             ...         ...           ...
# 54884          7006        2638  2.070378e+18
# 54885          9328        2638  1.314965e+18
# 54886          3601        2638  1.020675e+18
# 54887          3862        2638  1.350550e+18
# 54888         12338        2638  1.020433e+18
# 54889          9304         365  5.000000e+17
# 54890          6011        1767  1.010000e+18
# 54891          2200        4878  1.401789e+18
# 54892          2200        6198  1.282603e+18
# 54893          8274        2638  3.244233e+18
# 54894         12259        2638  3.072495e+18
# 54895          6674        2638  5.156724e+18
# 54896          9421        2638  1.039530e+18
# 54897         12096        2638  2.499937e+19
# 54898          9564        2638  7.013458e+18
# 54899          2692        2638  1.194486e+18
# 54900          3822        2638  2.240646e+18
# 54901          1777        2638  2.020629e+18
# 54902          6153        2638  1.605637e+18
# 54903          9385        2638  5.094139e+18
# 54904          2571        2638  1.075903e+18
# 54905         11888       12538  1.981314e+19
# 54906         10687        2638  1.354937e+18
# 54907          6680        2638  5.759678e+18
# 54908         10192        2638  4.126316e+18
# 54909          6756        2638  1.424968e+18
# 54910          5744        2638  5.099932e+18
# 54911          3479        2638  1.360934e+18
# 54912         10958        2638  1.243588e+18
# 54913         12174        2638  2.838278e+18
#
# [54914 rows x 3 columns]

# %%
g.get_edges()[0]
# Out:
# array([    0,  1012, 32522], dtype=uint64)

# %%
data2[data2['from_address'] == 0 ]
# Out:
#        from_address  to_address         value
# 32522             0        1012  1.664428e+20

# %%
bv, be = betweenness(g)
be.a /= be.a.max() / 5
graph_draw(g, vertex_fill_color=bv, edge_pen_width=be)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f741c8f1208, at 0x7f741c8f17b8>

# %%
be.a
# Out:
# PropertyArray([1.80585814e-04, 8.93864587e-10, 8.93864587e-10, ...,
#                3.20575765e-04, 3.61210595e-04, 1.54827992e-04])

# %%
m = np.array(bv.a).mean() # Moyenne des centralités d'intermédiarité
print(m)
# Out:
# 1.780524275420742e-05

# %%
sigma2 = (np.array(bv.a).std())**2 # variance des centralités d'intermédiarité
print(sigma2)
# Out:
# 5.473912033781246e-07

# %%
np.array(bv.a)[np.array(bv.a) > m + 3*sigma2] # 3*sigma a corriger

# %%
np.sum(np.array(bv.a) > m + 3*sigma2)

# %%
np.quantile(np.array(bv.a),3/4) # quantile 3/4

# %%
np.quantile(np.array(bv.a),1/4) # quantile 1/4

# %%
eiq = np.quantile(np.array(bv.a),3/4) - np.quantile(np.array(bv.a),1/4)

# %%
treshold  = np.quantile(np.array(bv.a),3/4) + 1.5*eiq

# %%
outliers = np.array(bv.a)[np.array(bv.a) > treshold]

# %%
[np.array(bv.a) > treshold]
# Out:
# [array([ True, False, False, ...,  True,  True, False])]

# %%
np.argwhere([np.array(bv.a) > treshold])[:,1]
# Out:
# array([    0,     7,    12, ..., 12858, 12859, 12860])

# %%
out_df = pd.DataFrame(np.argwhere([np.array(bv.a) > treshold])[:,1],columns=['addresses'])

# %%
Encoder.inverse_transform(out_df['addresses'])
# Out:
# array(['0x0000309bc0e82b9ac00244bbfb838d2e911cf4d5',
#        '0x000a4e0c3fcfd7254a32f07d6b4e633e4f17c02d',
#        '0x001217d58699efcceb05f785a969902d4172cfb6', ...,
#        '0xfffa3d1a8fee91a6dea912a7aa5af9351e6d9b1d',
#        '0xfffbca3a38c3c5fcb3adbb8e63c04c3e629aafce',
#        '0xfffc4575b80a7f4687571c3cb3e76b096eee45b9'], dtype=object)

# %%
outliers
# Out:
# array([7.39755609e-06, 2.78948629e-04, 5.66828802e-08, ...,
#        1.47951122e-05, 1.47951122e-05, 1.47951122e-05])

# %%
len(outliers)
# Out:
# 2739

# %%
eiq = np.quantile(np.array(be.a),3/4) - np.quantile(np.array(be.a),1/4)

# %%
treshold  = np.quantile(np.array(be.a),3/4) + 1.5*eiq

# %%
outliers = np.array(be.a)[np.array(be.a) > treshold]

# %%
np.argwhere(np.array(be.a) > treshold)
# Out:
# array([[    3],
#        [    4],
#        [    6],
#        ...,
#        [54905],
#        [54908],
#        [54910]])

# %%
d_out_e = pd.DataFrame(np.argwhere(np.array(be.a) > treshold),columns=['graph_index'])

# %%
d_out_e
# Out:
# Empty DataFrame
# Columns: []
# Index: [3, 4, 6, 7, 8, 10, 11, 12, 14, 15, 17, 26, 31, 34, 39, 43, 46, 57, 59, 60, 62, 63, 64, 65, 68, 71, 72, 75, 78, 81, 83, 84, 85, 86, 98, 104, 122, 130, 131, 150, 152, 160, 162, 163, 164, 165, 168, 169, 170, 184, 185, 186, 187, 188, 198, 200, 224, 232, 233, 251, 252, 259, 261, 267, 270, 298, 300, 335, 344, 348, 350, 359, 360, 361, 362, 372, 376, 413, 414, 450, 462, 467, 468, 479, 480, 481, 484, 485, 486, 487, 488, 497, 516, 540, 542, 544, 546, 569, 581, 586, ...]
#
# [9076 rows x 0 columns]

# %%
d_out_e.set_index('graph_index',inplace=True)

# %%
df_edges = pd.DataFrame(g.get_edges(),columns=['from','to','index'])

# %%
df_edges.set_index('index',inplace=True)

# %%
df_edges
# Out:
#         from     to
# index
# 32522      0   1012
# 11066      2   3959
# 4681       3   2140
# 4153       5  10359
# 4248       5  10359
# 36382      7  10317
# 37141      7   5072
# 37411      7   8103
# 37502      7   3841
# 37612      7   3058
# 40438      7   3603
# 40622      7  12707
# 40836      7   2282
# 761       12   2638
# 6729      12   2638
# 10035     12   2638
# 15247     12   2638
# 21286     12   2638
# 27781     12   2638
# 40383     12   2638
# 41953     12   2638
# 47707     12   2638
# 51027     12   2638
# 12579     13   8215
# 30447     17   2978
# 21658     25   5917
# 21746     25  11950
# 16285     27    188
# 11105     29   7549
# 28264     31   5896
# ...      ...    ...
# 54826  12833   2638
# 32363  12836   2638
# 13481  12838   8465
# 13999  12838  12312
# 28253  12838  12312
# 28302  12838   8465
# 31116  12838   8465
# 31119  12838  12312
# 32018  12838   7663
# 35087  12838  12312
# 37638  12838  12312
# 21311  12839   2638
# 51328  12839   2638
# 21163  12841   5761
# 11477  12842   2638
# 32506  12844   2638
# 7048   12848   1012
# 3750   12849   2904
# 42719  12852   3529
# 27083  12853  11885
# 19463  12854   7655
# 19561  12854   6763
# 52844  12856   2723
# 53122  12856   2723
# 49648  12857   7144
# 32279  12858   2638
# 1797   12859   2638
# 39381  12859   2638
# 51008  12859   2638
# 50076  12860   1012
#
# [54914 rows x 2 columns]

# %%
df_edges_out = d_out_e.merge(df_edges,left_index=True,right_index=True)

# %%
df_edges_out
# Out:
#         from     to
# 3       1125   2638
# 4       4036   2638
# 6       2638   2299
# 7       1196   2638
# 8       2638   2339
# 10      2638   1771
# 11      1156   2638
# 12      2638   5298
# 14      2638   7345
# 15      2638   8944
# 17      1584   6690
# 26      5387   1474
# 31      8293   8616
# 34      9236   1077
# 39     11888  11854
# 43      1012   1740
# 46      1012   5140
# 57      9370   7628
# 59      5761   4714
# 60     11854  12659
# 62       927   1012
# 63      1474   1012
# 64      7141   1012
# 65       482    747
# 39     0xecbee6d4ea68b5f948f3a211ff066cd4b7c03187
# 43     0x211bf36a4b8e0607d879021a627ae9754674de01
# 46     0x65187f5c5eaa61ccaf573054a66b093d99fd75f1
# 57     0x96aa366d0e8de9f6c1693aafe86565831f157e56
# 59     0x5c70eb0e8923cc0c416e8fa002ad165c9cfcfb24
# 60     0xfbb1b73c4f0bda4f67dca266ce6ef42f520fbb98
# 62     0x120a270bbc009644e35f0bb6ab13f95b8199c4ad
# 63     0x120a270bbc009644e35f0bb6ab13f95b8199c4ad
# 64     0x120a270bbc009644e35f0bb6ab13f95b8199c4ad
# 65     0x0d1c130b30117b75206cc2df043e6046a14518d1
# 68     0xfbb1b73c4f0bda4f67dca266ce6ef42f520fbb98
# 71     0xfbb1b73c4f0bda4f67dca266ce6ef42f520fbb98
# 72     0x32be343b94f860124dc4fee278fdcbd38c102d88
# 75     0x211bf36a4b8e0607d879021a627ae9754674de01
# 78     0x81eb804249363ccc2ecad2a7474285a871d62858
# 81     0x32be343b94f860124dc4fee278fdcbd38c102d88
# ...                                           ...
# 54792  0xeab60df1c550eb20361968a832cd620d898acc64
# 54794  0x061e3e5c2e37889da3682872e949aff6eb98a8ba
# 54796  0xa81737972a1842319fe61af336117042e4f324cc
# 54800  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54801  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54814  0x95615e169768b75e7941d3207c2efbdf60f54c76
# 54829  0xcd9e78b6a616f8a8fe89b5142ed81286bcbec168
# 54842  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54845  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54849  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54855  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54865  0xc2cfe5a3f93ec99919a0250cea40e22b26342fac
# 54866  0xca1de67459bd59c5f82e024110a970a1ea91f407
# 54873  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54879  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54883  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54884  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54887  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54889  0x056507108fe6d30189eccd6cd7f4fad56eeef622
# 54890  0x21988dde5955364421a07beb86fa8d723be5799d
# 54894  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54895  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54896  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54897  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54898  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54901  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54903  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54905  0xf96737fd9c93fecc7e1c98728902508231b1f646
# 54908  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54910  0x32be343b94f860124dc4fee278fdcbd38c102d88
#
# [9076 rows x 4 columns]

# %%
data2[data2['from_address'] == 12860]
# Out:
#        from_address  to_address         value
# 50076         12860        1012  7.169777e+19

# %%
data2[data2['to_address'] == 12860]
# Out:
#        from_address  to_address         value
# 50045          2273       12860  7.169819e+19

# %%
import matplotlib.pyplot as plt 
plt.boxplot(np.array(bv.a))
plt.show()

# %%
plt.hist(bv.a)

# %%
ew.a # On récupère les poids
# Out:
# PropertyArray([1.11955450e+17, 1.00000000e+00, 1.00000000e+00, ...,
#                1.36093416e+18, 1.24358780e+18, 2.83827838e+18])

# %%
transactionsweights = ew.a

# %%
ewq34 = np.quantile(np.array(ew.a),3/4) # quantile 3/4

# %%
ewq14 = np.quantile(np.array(ew.a),1/4) # quantile 1/4

# %%
ewiq = ewq34 - ewq14

# %%
len(transactionsweights[transactionsweights > 1.5*ewiq])
# Out:
# 11781

# %%
plt.boxplot(np.array(transactionsweights))

# %%
transactionsweights[transactionsweights > 1.5*ewiq] 
# On va partir du principe que les adresses qui ont de gros volumes de transaction + une fréquence importante + 
# une centralité forte sont des outliers
# Out:
# PropertyArray([9.99937000e+18, 7.02371600e+18, 4.95518193e+18, ...,
#                5.75967840e+18, 4.12631593e+18, 5.09993187e+18])

# %%
len(transactionsweights > 1.5*ewiq)
# Out:
# 54914

# %%
len(np.argwhere(transactionsweights > 1.5*ewiq))
# Out:
# 11781

# %%
m_ew, std = edge_average(g,ew) # average and std

# %%
np.sum(np.array(ew.a) > m_ew + 3*std)

# %%
plt.hist(np.array(ew.a))

# %%
g.edges

# %%
2833/54914

# %%
para = label_parallel_edges(g)

# %%
para.a
# Out:
# PropertyArray([ 0,  0,  1, ...,  8,  7, 18], dtype=int32)

# %%
nb_para = np.array(para.a)

# %%
q34 = np.quantile(nb_para,3/4) # quantile 3/4

# %%
q14 = np.quantile(nb_para,1/4) # quantile 3/4

# %%
tauiq = q34 - q14

# %%
nb_para[nb_para > q34 + 1.5*tauiq]
# Out:
# array([  13,   14,   13, ...,   18, 1315,   18], dtype=int32)

# %%
len(np.argwhere(nb_para[nb_para > q34 + 1.5*tauiq]))
# Out:
# 8986

# %%
np.max(para.a)
# Out:
# PropertyArray(3097, dtype=int32)

# %%
np.argmax([para.a == 3097])

# %%
g.get_edges()

# %%
df_edges = pd.DataFrame(g.get_edges(),columns=['from','to','index'])

# %%
df_edges[df_edges['index'] == 54496]

# %%
data2.loc[( data2['from_address'] == 5075 ) & ( data2['to_address'] == 1648 )]

# %%
Encoder.inverse_transform(df_edges[df_edges['index'] == 5075]['from'])

# %%
Encoder.inverse_transform(df_edges[df_edges['index'] == 1648]['to'])

# %%
g.get_in_degrees([1648],eweight=ew) # nombre de degrés entrants

# %%
g.get_edges().shape

# %%
graph_draw(g)

# %%
g.list_properties()
# Out:
# edge_weight    (edge)    (type: double)

# %%
ew
# Out:
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x7f741c8f1208, at 0x7f741c8f1390>

# %%
g.ep['edge_weight']
# Out:
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x7f741c8f1208, at 0x7f741c8f1390>

# %%
# Ici on a une matrice constituée de depart / arrivée / id
g.get_edges()

# %%
# On compare au tableau des transactions

data2[data2['from_address'] == 12859]

# %%
# On compare au tableau des transactions

data2[data2['from_address'] == 0]

# %%
# On compare au tableau des transactions

data2[data2['from_address'] == 2]

# %% [markdown]
# ## Fonctions

# %%
def transaction_outlier(graph,coeff_lambda=1.5):
    """
    Prend en arguments le graphe de transactions à étudier, et lambda permettant d'ajuster le seuil 
    Renvoie les outliers selon le montant des transactions/eweights associés au graphe 
    sous forme d'un DF pandas 
    
    """
    g = graph
    ew = g.ep['edge_weight']
    
    # On récupère les poids 
    tweights = np.array(ew.a)
    
    # Ecart interquartile
    twq34 = np.quantile(tweights,3/4) # quantile 3/4
    twq14 = np.quantile(tweights,1/4) # quantile 1/4
    tauiq = twq34 - twq14
    
    # Seuillage
    index = np.argwhere(tweights > coeff_lambda*tauiq) # Index des transactions outliers
    values = tweights[tweights > coeff_lambda*tauiq]   # Montant des transactions outliers 
    
    # Préparation du tableau
    
    d_out_e = pd.DataFrame(index,columns=['e_index']) # tableau des arêtes outliers
    df_edges = pd.DataFrame(g.get_edges(),columns=['from','to','index']) # tableau complet des arêtes    
    
    d_out_e.set_index('e_index',inplace=True) # changement des index pour un inner join
    df_edges.set_index('index',inplace=True) # changement des index pour un inner join    
    
    df_edges_out = d_out_e.merge(df_edges,left_index=True,right_index=True) # jointure interieure
    
    
    # On réencode les adresses
    df_edges_out['from_address'] = Encoder.inverse_transform(df_edges_out['from'])
    df_edges_out['to_address'] = Encoder.inverse_transform(df_edges_out['to'])
    df_edges_out['value'] = values
    return(df_edges_out)

# %%
df_test = transaction_outlier(g)

# %%
df_test
# Out:
#         from     to                                from_address  \
# 3       1125   2638  0x1431354497e6e11e24ec3fe9a76d4f7897e2a712
# 4       4036   2638  0x4eb44a2d45370a8fe762040447112a6ce42ca6a2
# 5       1183   2638  0x1543667b9bad3e41865c3233e1764d8dda8e1f3d
# 6       2638   2299  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 9       2727   2638  0x34420d02a652c40dfbb10d09c99c9a4e39e94477
# 12      2638   5298  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 13      6641   2638  0x826607e5cd885df632068f1179ddf47fdd92bd2b
# 14      2638   7345  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 15      2638   8944  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 20      3888   7778  0x4bb96091ee9d802ed039c4d1a5f6216f90f81b01
# 24     10123   9480  0xc862c9b0064e41c8150f158a2df0fbcba0131266
# 30      3888  12473  0x4bb96091ee9d802ed039c4d1a5f6216f90f81b01
# 36      3888  11387  0x4bb96091ee9d802ed039c4d1a5f6216f90f81b01
# 38      3888   8871  0x4bb96091ee9d802ed039c4d1a5f6216f90f81b01
# 39     11888  11854  0xed6b25b3b2dab2d5d96ac659aabbf812f069351b
# 42      1012   2792  0x120a270bbc009644e35f0bb6ab13f95b8199c4ad
# 43      1012   1740  0x120a270bbc009644e35f0bb6ab13f95b8199c4ad
# 46      1012   5140  0x120a270bbc009644e35f0bb6ab13f95b8199c4ad
# 48      5075   7898  0x63a9975ba31b0b9626b34300f7f627147df1f526
# 57      9370   7628  0xb9c18f099cb151f0dbaaccf2b49314a653ddc2f2
# 59      5761   4714  0x7180eb39a6264938fdb3effd7341c4727c382153
# 60     11854  12659  0xecbee6d4ea68b5f948f3a211ff066cd4b7c03187
# 62       927   1012  0x107674d7168a84491c3a21cf33d7a774ba5b8bdb
# 64      7141   1012  0x8c8b21bd0aae432c40b6e89cf5a9ab74d77ea3ec
# 72      8871   2638  0xaf9a2324a9c4bab10d5d0c0709531a4d9f1c4384
# 73      3974   2638  0x4d67f4f0db45b3b5a3424b39ed8d972f710381d5
# 74     12473   2638  0xf87481a262e993a75f791e7859e71bac36a606eb
# 75      1012   1740  0x120a270bbc009644e35f0bb6ab13f95b8199c4ad
# 78      2638   6609  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 79      7898   2638  0x9c578a52a1b7ed9fdcffd504142fecd8cdabe709
# ...      ...    ...                                         ...
# 54804  12006   2638  0xefa8becf5a1f7817a01556559bd3fb2e1f6eadee
# 54807  12018   2638  0xf000d531b485d3fc32ed670b26509813d8f47008
# 54812   1972   2638  0x25d855a7a140ac6f330e2202f96c6f62eb126cc1
# 54814  10495   7561  0xd0317e8d007a61b8d740516e8a268d4fadadccbf
# 54816   7729   2638  0x990eb878dfff8b7e99aab256f7d4b970326a9fba
# 54819  11176   2638  0xdf257408c85c0e02af46433ff76081917d8e032d
# 54883  0x32be343b94f860124dc4fee278fdcbd38c102d88  2.521578e+19
# 54895  0x32be343b94f860124dc4fee278fdcbd38c102d88  5.156724e+18
# 54897  0x32be343b94f860124dc4fee278fdcbd38c102d88  2.499937e+19
# 54898  0x32be343b94f860124dc4fee278fdcbd38c102d88  7.013458e+18
# 54903  0x32be343b94f860124dc4fee278fdcbd38c102d88  5.094139e+18
# 54905  0xf96737fd9c93fecc7e1c98728902508231b1f646  1.981314e+19
# 54907  0x32be343b94f860124dc4fee278fdcbd38c102d88  5.759678e+18
# 54908  0x32be343b94f860124dc4fee278fdcbd38c102d88  4.126316e+18
# 54910  0x32be343b94f860124dc4fee278fdcbd38c102d88  5.099932e+18
#
# [11781 rows x 5 columns]

# %%
data2[data2['from_address'] == 4036]
# Out:
#    from_address  to_address         value
# 4          4036        2638  7.023716e+18

# %%
def between_outlier(graph,coeff_lambda=1.5,nodes=True):
    """
    Prend en arguments le graphe de transactions à étudier, et lambda permettant d'ajuster le seuil 
    Renvoie les outliers au sens de la centralité d'intermédiarité 
    sous forme d'un DF pandas 
    
    """
    g = graph
    # On récupère les centralités d'intermédiarité de chaque noeuds (bv) et chaque arête (be)
    bv, be = betweenness(g)
    
    if nodes:
        q34 = np.quantile(np.array(bv.a),3/4)
        q14 = np.quantile(np.array(bv.a),1/4)
        
        # Ecart interquartile
        tauiq = q34 - q14
        
        # Seuillage
        treshold  = np.quantile(np.array(bv.a),3/4) + coeff_lambda*tauiq
        outliers = np.array(bv.a)[np.array(bv.a) > treshold]
        outliers_index = np.argwhere([np.array(bv.a) > treshold])[:,1]
        
        
        # On prépare le tableau 
        
        df = pd.DataFrame(outliers_index,columns=['v_index'])
        df['address'] = Encoder.inverse_transform(df['v_index'])
        
        return(df)
    
    else:

        q34 = np.quantile(np.array(be.a),3/4)
        q14 = np.quantile(np.array(be.a),1/4)
        
        # Ecart interquartile
        tauiq = q34 - q14
        
        # Seuillage
        treshold  = np.quantile(np.array(be.a),3/4) + coeff_lambda*tauiq
        outliers = np.array(be.a)[np.array(be.a) > treshold]
        outliers_index = np.argwhere(np.array(be.a) > treshold)
        
        
        # On prépare le tableau   
        d_out_e = pd.DataFrame(outliers_index,columns=['e_index']) # tableau des arêtes outliers
        df_edges = pd.DataFrame(g.get_edges(),columns=['from','to','index']) # tableau complet des arêtes
        
        d_out_e.set_index('e_index',inplace=True) # changement des indexs pour un inner join
        df_edges.set_index('index',inplace=True) # changement des indexs pour un inner join
        
        df_edges_out = d_out_e.merge(df_edges,left_index=True,right_index=True) # jointure interieure
        
        # On réencode les adresses
        df_edges_out['from_address'] = Encoder.inverse_transform(df_edges_out['from'])
        df_edges_out['to_address'] = Encoder.inverse_transform(df_edges_out['to'])
        
        return(df_edges_out)

# %%
df_test = between_outlier(g,nodes=False)

# %%
df_test
# Out:
#         from     to                                from_address  \
# 3       1125   2638  0x1431354497e6e11e24ec3fe9a76d4f7897e2a712
# 4       4036   2638  0x4eb44a2d45370a8fe762040447112a6ce42ca6a2
# 6       2638   2299  0x32be343b94f860124dc4fee278fdcbd38c102d88
#
0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54801  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54814  0x95615e169768b75e7941d3207c2efbdf60f54c76
# 54829  0xcd9e78b6a616f8a8fe89b5142ed81286bcbec168
# 54842  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54845  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54849  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54855  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54865  0xc2cfe5a3f93ec99919a0250cea40e22b26342fac
# 54866  0xca1de67459bd59c5f82e024110a970a1ea91f407
# 54873  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54879  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54883  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54884  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54887  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54889  0x056507108fe6d30189eccd6cd7f4fad56eeef622
# 54890  0x21988dde5955364421a07beb86fa8d723be5799d
# 54894  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54895  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54896  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54897  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54898  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54901  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54903  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54905  0xf96737fd9c93fecc7e1c98728902508231b1f646
# 54908  0x32be343b94f860124dc4fee278fdcbd38c102d88
# 54910  0x32be343b94f860124dc4fee278fdcbd38c102d88
#
# [9076 rows x 4 columns]

# %%
def parallel_outlier(graph,coeff_lambda=1.5):
    """
    Prend en arguments le graphe de transactions à étudier, et lambda permettant d'ajuster le seuil 
    Renvoie les outliers au sens des transactions parallèles 
    sous forme d'un DF pandas 
    
    """
    g = graph
    para = label_parallel_edges(g)
    nb_para = np.array(para.a)
    
    # Ecart interquartile
    q34 = np.quantile(nb_para,3/4) # quantile 3/4
    q14 = np.quantile(nb_para,1/4) # quantile 1/4
    tauiq = q34 - q14
    
    # Seuillage
    treshold = q34 + coeff_lambda*tauiq
    outliers_index = np.argwhere(nb_para > treshold)
    outliers = nb_para[nb_para > treshold]
    
    
    
    # On prépare le tableau   
    d_out_e = pd.DataFrame(outliers_index,columns=['e_index']) # tableau des arêtes outliers
    df_edges = pd.DataFrame(g.get_edges(),columns=['from','to','index']) # tableau complet des arêtes
        
    d_out_e.set_index('e_index',inplace=True) # changement des indexs pour un inner join
    df_edges.set_index('index',inplace=True) # changement des indexs pour un inner join
        
    df_edges_out = d_out_e.merge(df_edges,left_index=True,right_index=True) # jointure interieure
        
    # On réencode les adresses
    df_edges_out['from_address'] = Encoder.inverse_transform(df_edges_out['from'])
    df_edges_out['to_address'] = Encoder.inverse_transform(df_edges_out['to'])
    df_edges_out['number_parallel_transactions'] = outliers
    
    return(df_edges_out)

# %%
parallel_outlier(g)
# Out:
#         from     to                                from_address  \
# 101     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 107     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 121     5075   1648  0x63a9975ba31b0b9626b34300f7f627147df1f526
# 123     5075   1648  0x63a9975ba31b0b9626b34300f7f627147df1f526
# 124     5075   1648  0x63a9975ba31b0b9626b34300f7f627147df1f526
# 125     5075   1648  0x63a9975ba31b0b9626b34300f7f627147df1f526
# 126     5075   1648  0x63a9975ba31b0b9626b34300f7f627147df1f526
# 167     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 173     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 182     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 197     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 205     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 209     5075   1648  0x63a9975ba31b0b9626b34300f7f627147df1f526
# 210     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 211     5075   1648  0x63a9975ba31b0b9626b34300f7f627147df1f526
# 227     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 246     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 257     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 258     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 277     1664   7823  0x1f93b5e75a04b225816935c3d65f552cac88a61b
# 281     9883   7823  0xc400b9d93a23b0be5d41ab337ad605988aef8463
#
# 54685                            42
# 54688                            43
# 54712                          1313
# 54730                            15
# 54737                          1314
# 54745                           233
# 54746                          1179
# 54751                            30
# 54753                           119
# 54757                          1180
# 54767                            28
# 54815                            20
# 54825                            18
# 54836                            18
# 54844                          1315
# 54913                            18
#
# [8986 rows x 5 columns]

# %% [markdown]
# # Création de fonctions d'import

# %%
import glob

def aggregate_csv():
    """
    Concatene les csv présents dans le répertoire courant, 
    Renvoie un pandas DF résultant de la concaténation
    
    """
    extension = 'csv'
    all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
    combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
    combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
    return(combined_csv)

# %%
full_data = aggregate_csv()

# %%
full_data.head()

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import LabelEncoder




def format_as_tgraph(data):
    """
    Formatage d'un pandas DF en un pandas DF adapté
    à un import en graphe de transactions: 
    
    Renvoie un pandas DF dans un format adapté a un import graphique
    
    """
    
    # On transforme les addresses en str pour éviter les ennuis
    data[['from_address', 'to_address']] = data[['from_address', 'to_address']].astype(str)

    
    # On concatene les addresses pour éviter les doublons 
    
    full_addresses = np.append(data['from_address'].values,data['to_address'].values)
    
    
    # Encodage des addresses sur la liste ENTIERE des addresses 
    Encoder = LabelEncoder()
    Encoder.fit(full_addresses) #Apprend sur les addresses 

    new_from = Encoder.transform(data['from_address']) # On transforme
    new_to = Encoder.transform(data['to_address'])     # On transforme
    
    
    # Remplacement des colonnes par les colonnes ainsi encodées
    data['from_address'] = new_from
    data['to_address'] = new_to
    
    # On transforme la colonne value en float
    data[['value']] = data[['value']].astype(float)
    
    
    return(data)

# %%
full_data_graph = format_as_tgraph(full_data)

# %%
full_data_graph.head()

# %%
from graph_tool.all import *


def create_graph_obj(data):
    """
    Prend un pandas DF formaté correctement en transaction graph
    Crée et renvoie un objet graph-tool sur lequel on peut travailler
    
    """
    
    # Création du graphe vide
    g = Graph(directed=True) 

    # Ajout des arêtes suivant le np.array
    vmap = g.add_edge_list(data[['from_address','to_address']].values)

    # Ajout des edge weights 
    ew = g.new_edge_property("double")
    ew.a = data['value'].values
    g.ep['edge_weight'] = ew
    
    return(g)

# %%
g = create_graph_obj(full_data_graph)

# %%
graph_draw(g)

# %%
weights = g.edge_properties['edge_weight']

# %%
pos = sfdp_layout(g,eweight=weights)
graph_draw(g,pos=pos)

# %%
adj_m = adjacency(g)

# %%
degs = adj_m.sum(axis=0)

# %%
v_number = np.max(g.get_vertices())

# %%
deg_moy = np.sum(degs)/v_number

# %%
deg_moy

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
g.get_vertices()

# %%
g.get_edges()

# %%
np.unique(np.append(full_data_graph['from_address'].values,full_data_graph['to_address'].values))

# %%
len(vertex_hist(g, deg='in', bins=[0, 1], float_count=True)[0])

# %%
plt.hist(vertex_hist(g, deg='in', bins=[0, 1], float_count=True)[0])

# %%
plt.hist(vertex_hist(g, deg='out', bins=[0, 1], float_count=True)[0])

# %%
edge_average(g,g.ep['edge_weight'])

# %%
vertex_hist(g,'in',bins=[0,1])
