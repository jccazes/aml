# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("transactions_01160000_01169999.csv",sep=',')

# %%
data.head()
# Out:
#                                                 hash  nonce  \
# 0  0xba048f59c055470fed2668d2d040879ab5ef5dfc106c...     42
# 1  0x0a1807644cef7ea7eca30c075512b1136c28b24ac538...  37665
# 2  0x4d1ebaeddfdf5db17a83753003f6eaa50841b599ef15...  37666
# 3  0xac1baec5b7ce60fa5b7afcb1f362e41c5cb529384e69...     14
# 4  0xda255e01a213a47f3454e085681198f48b61ea947ab4...    138
#
#                                           block_hash  block_number  \
# 0  0xcb16bbb2b7b593f506369f0174355254485960fba2cd...       1160100
# 1  0x62ee818f0b2b3047bd725317e820d83f0f5c5b9971b1...       1160101
# 2  0x62ee818f0b2b3047bd725317e820d83f0f5c5b9971b1...       1160101
# 3  0x40fc1e112e67eb5ad1cef2517dcce281fd43d18349d9...       1160104
# 4  0x40fc1e112e67eb5ad1cef2517dcce281fd43d18349d9...       1160104
#
#    transaction_index                                from_address  \
# 0                  0  0xc5698e5ed169e2ff546455c0431543bc641fdb20
# 1                  0  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 2                  1  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 3                  0  0x1431354497e6e11e24ec3fe9a76d4f7897e2a712
# 4                  1  0x4eb44a2d45370a8fe762040447112a6ce42ca6a2
#
#                                    to_address                value     gas  \
# 0  0x1699333a4e46093e15a94b4a213b88eb8a963834   111955450000000000   21000
# 1  0x9af09991ad63814e53ffc1bccf213ee74027608b                    1  300000
# 2  0x9af09991ad63814e53ffc1bccf213ee74027608b                    1  300000
# 3  0x32be343b94f860124dc4fee278fdcbd38c102d88  9999370000000000000   21000
# 4  0x32be343b94f860124dc4fee278fdcbd38c102d88  7023716000000000000   21000
#
#      gas_price                                              input
# 0  50000000000                                                 0x
# 1  52000000000  0x3ed4867900000000000000000000000036c425e72bbc...
# 2  52000000000  0x3ed48679000000000000000000000000490c0dd13bfe...
# 3  30000000000                                                 0x
# 4  30000000000                                                 0x

# %%
print(len(data['from_address'].unique()))
print(len(data['to_address'].unique()))
# Out:
# 6618
# 11960

# %%
data.dtypes
# Out:
# hash                 object
# nonce                 int64
# block_hash           object
# block_number          int64
# transaction_index     int64
# from_address         object
# to_address           object
# value                object
# gas                   int64
# gas_price             int64
# input                object
# dtype: object

# %%
# On transforme les addresses en str pour éviter les ennuis

data[['from_address', 'to_address']] = data[['from_address', 'to_address']].astype(str)

# %%
# Vérifications

c = 0
for add in data['from_address'].values:
    if type(add) != str:
        c += 1
        
c
# Out:
# 0

# %%
# Vérifications

c = 0
for add in data['to_address'].values:
    if type(add) != str:
        c += 1
        
c
# Out:
# 0

# %%
full_addresses = np.append(data['from_address'].values,data['to_address'].values)
full_addresses
# Out:
# array(['0xc5698e5ed169e2ff546455c0431543bc641fdb20',
#        '0xc400b9d93a23b0be5d41ab337ad605988aef8463',
#        '0xc400b9d93a23b0be5d41ab337ad605988aef8463', ...,
#        '0x32be343b94f860124dc4fee278fdcbd38c102d88',
#        '0x32be343b94f860124dc4fee278fdcbd38c102d88',
#        '0x32be343b94f860124dc4fee278fdcbd38c102d88'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

Encoder = LabelEncoder()
Encoder.fit(full_addresses) #Apprend sur les addresses 

new_from = Encoder.transform(data['from_address']) # On transforme
new_to = Encoder.transform(data['to_address'])     # On transforme

# %%
data['from_address'] = new_from
data['to_address'] = new_to

# %%
# On transforme la colonne value en float
data[['value']] = data[['value']].astype(float)

# %%
# On utilise le tableau partiel avec les addresses et les montants transférés
data2 = data[['from_address','to_address','value']]

# %%
data2.head()
# Out:
#    from_address  to_address         value
# 0          9959        1235  1.119554e+17
# 1          9883        7823  1.000000e+00
# 2          9883        7823  1.000000e+00
# 3          1125        2638  9.999370e+18
# 4          4036        2638  7.023716e+18

# %%
# On somme les transactions entre meme personnes 
df = data2.groupby(['from_address','to_address']).sum()

# %%
def Missing_values(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total,percent], axis=1, keys=['Total', 'Pourcentage'])
    #Affiche que les variables avec des na
    print (missing_data[(percent>0)],'\n' )

# %%
Missing_values(data2)
Missing_values(df)
# Out:
# Empty DataFrame
# Columns: [Total, Pourcentage]
# Index: []
#
# Empty DataFrame
# Columns: [Total, Pourcentage]
# Index: []

# %%
# a rajouter, une colonne avec les balances en vertice property

# %%
df
# Out:
#                                 value
# from_address to_address
# 0            1012        1.664428e+20
# 2            3959        5.000000e+18
# 3            2140        5.000000e+17
# 5            10359       1.100000e+18
# 7            2282        9.400000e+19
#              3058        3.200000e+19
#              3603        9.360000e+19
#              3841        9.500000e+19
#              5072        9.500000e+19
#              8103        9.500000e+19
#              10317       9.500000e+19
#              12707       9.400000e+19
# 12           2638        2.241353e+19
# 13           8215        1.500000e+19
# 17           2978        5.000000e+17
# 25           5917        2.000000e+18
#              11950       2.000000e+18
# 27           188         1.000000e+18
# 29           7549        3.000000e+18
# 31           5896        5.957200e+17
# 36           5893        4.010000e+18
# 37           1914        7.705119e+18
#              6042        1.500000e+19
# 39           2638        8.933700e+18
# 41           2638        7.199370e+18
# 43           2638        3.404078e+19
# 48           2846        1.200000e+18
# 49           2638        1.046544e+18
# 50           1012        3.038620e+17
# 56           47          1.000000e+18
# ...                               ...
# 12817        2888        5.000000e+17
# 12818        2638        4.327499e+19
# 12819        6683        2.100000e+18
# 12820        12659       8.438417e+18
# 12821        2638        2.095443e+18
# 12824        2638        2.241018e+19
# 12827        5761        1.384273e+22
# 12828        2638        4.648744e+18
# 12829        9521        1.423900e+18
# 12831        2638        1.299370e+18
# 12833        2638        8.671404e+18
# 12836        2638        1.389370e+18
# 12838        7663        2.500000e+19
#              8465        4.500000e+20
#              12312       5.000000e+20
# 12839        2638        2.260614e+18
# 12841        5761        3.495000e+16
# 12842        2638        1.089943e+18
# 12844        2638        1.039370e+18
# 12848        1012        7.499958e+19
# 12849        2904        1.000000e+18
# 12852        3529        2.000000e+18
# 12853        11885       2.000000e+18
# 12854        6763        2.500000e+21
#              7655        1.000000e+18
# 12856        2723        1.150000e+20
# 12857        7144        8.100000e+19
# 12858        2638        5.779994e+20
# 12859        2638        2.870797e+20
# 12860        1012        7.169777e+19
#
# [18915 rows x 1 columns]

# %% [markdown]
# # Import sous GraphTool

# %%
from graph_tool.all import *

# %%
# Création du graphe vide
g = Graph(directed=True) 

# Ajout des arêtes suivant le np.array
vmap = g.add_edge_list(data2[['from_address','to_address']].values)

# Ajout des edge weights 
ew = g.new_edge_property("double")
ew.a = data2['value'].values
g.ep['edge_weight'] = ew

# %%
data2
# Out:
#        from_address  to_address         value
# 0              9959        1235  1.119554e+17
# 1              9883        7823  1.000000e+00
# 2              9883        7823  1.000000e+00
# 3              1125        2638  9.999370e+18
# 4              4036        2638  7.023716e+18
# 5              1183        2638  4.955182e+18
# 6              2638        2299  4.093302e+19
# 7              1196        2638  1.386536e+18
# 8              2638        2339  1.999422e+18
# 9              2727        2638  4.949370e+18
# 10             2638        1771  9.900000e+17
# 11             1156        2638  1.419370e+18
# 12             2638        5298  1.799990e+21
# 13             6641        2638  4.976694e+18
# 14             2638        7345  7.754446e+18
# 15             2638        8944  3.996077e+18
# 16             8979        7177  6.231003e+17
# 17             1584        6690  1.020709e+18
# 18             1648       12659  2.804224e+18
# 19             9883        7823  1.000000e+00
# 20             3888        7778  4.950000e+18
# 21             1664        7823  1.000000e+00
# 22             3505        8948  1.000000e+17
# 23             9883        7823  1.000000e+00
# 24            10123        9480  9.871668e+18
# 25            10123        4163  9.871668e+16
# 26             5387        1474  1.000000e+18
# 27             1664        7823  1.000000e+00
# 28             9883        7823  1.000000e+00
# 29            11805        2303  1.610550e+15
# ...             ...         ...           ...
# 54884          7006        2638  2.070378e+18
# 54885          9328        2638  1.314965e+18
# 54886          3601        2638  1.020675e+18
# 54887          3862        2638  1.350550e+18
# 54888         12338        2638  1.020433e+18
# 54889          9304         365  5.000000e+17
# 54890          6011        1767  1.010000e+18
# 54891          2200        4878  1.401789e+18
# 54892          2200        6198  1.282603e+18
# 54893          8274        2638  3.244233e+18
# 54894         12259        2638  3.072495e+18
# 54895          6674        2638  5.156724e+18
# 54896          9421        2638  1.039530e+18
# 54897         12096        2638  2.499937e+19
# 54898          9564        2638  7.013458e+18
# 54899          2692        2638  1.194486e+18
# 54900          3822        2638  2.240646e+18
# 54901          1777        2638  2.020629e+18
# 54902          6153        2638  1.605637e+18
# 54903          9385        2638  5.094139e+18
# 54904          2571        2638  1.075903e+18
# 54905         11888       12538  1.981314e+19
# 54906         10687        2638  1.354937e+18
# 54907          6680        2638  5.759678e+18
# 54908         10192        2638  4.126316e+18
# 54909          6756        2638  1.424968e+18
# 54910          5744        2638  5.099932e+18
# 54911          3479        2638  1.360934e+18
# 54912         10958        2638  1.243588e+18
# 54913         12174        2638  2.838278e+18
#
# [54914 rows x 3 columns]

# %%
g.get_edges()[0]
# Out:
# array([    0,  1012, 32522], dtype=uint64)

# %%
data2[data2['from_address'] == 0 ]
# Out:
#        from_address  to_address         value
# 32522             0        1012  1.664428e+20

# %%
bv, be = betweenness(g)
be.a /= be.a.max() / 5
graph_draw(g, vertex_fill_color=bv, edge_pen_width=be)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f5be5909908, at 0x7f5be591cd68>

# %%
be.a
# Out:
# PropertyArray([1.80585814e-04, 8.93864587e-10, 8.93864587e-10, ...,
#                3.20575765e-04, 3.61210595e-04, 1.54827992e-04])

# %%
m = np.array(bv.a).mean() # Moyenne des centralités d'intermédiarité
print(m)
# Out:
# 1.7805242754207428e-05

# %%
sigma2 = (np.array(bv.a).std())**2 # variance des centralités d'intermédiarité
print(sigma2)
# Out:
# 5.473912033781254e-07

# %%
np.array(bv.a)[np.array(bv.a) > m + 3*sigma2] # 3*sigma a corriger
# Out:
# array([2.78948629e-04, 3.48685787e-05, 1.12628421e-04, 6.44285719e-05,
#        3.48867173e-05, 6.97613422e-05, 6.97613422e-05, 6.97613422e-05,
#        6.97432035e-05, 3.75732095e-05, 1.79781359e-04, 2.84171859e-04,
#        6.13919834e-05, 1.85143187e-04, 2.53413948e-04, 6.07085327e-05,
#        1.00912991e-04, 2.01509995e-04, 2.46726486e-04, 1.83895941e-04,
#        1.54408651e-04, 1.35630810e-04, 6.97371573e-05, 2.81571053e-05,
#        3.48806711e-05, 5.94038729e-05, 3.48685787e-05, 3.48806711e-05,
#        2.95902244e-05, 2.27443959e-04, 8.87706731e-05, 3.05585922e-05,
#        4.45963003e-05, 3.51901680e-05, 3.48685787e-05, 2.44080051e-04,
#        3.48685787e-05, 3.53013952e-05, 3.48685787e-05, 2.51087625e-04,
#        4.43853366e-05, 3.48806711e-05, 3.48564862e-05, 1.32177661e-04,
#        3.48685787e-05, 1.91972738e-03, 2.95720857e-05, 2.81789876e-05,
#        1.00317747e-04, 4.46000946e-04, 4.48630066e-02, 6.97432035e-05,
#        3.48806711e-05, 8.12127354e-04, 2.81571053e-05, 1.30992879e-04,
#        3.48806711e-05, 1.48884309e-03, 3.13961929e-05, 2.30361198e-04,
#        3.48711581e-05, 3.48685787e-05, 4.43430130e-05, 3.48685787e-05,
#        3.48806711e-05, 6.97371573e-05, 6.07085327e-05, 3.48685787e-05,
#        3.48806711e-05, 1.07862073e-04, 3.48867173e-05, 3.48806711e-05,
#        1.12628421e-04, 3.48806711e-05, 3.48685787e-05, 3.48806711e-05,
#        2.81571053e-05, 3.48685787e-05, 1.25031293e-03, 3.48685787e-05,
#        1.04605736e-04, 3.48806711e-05, 2.95902244e-05, 3.48685787e-05,
#        6.36220036e-05, 4.45963003e-05, 6.97432035e-05, 7.07691168e-04,
#        2.57240842e-05, 3.48806711e-05, 4.45963003e-05, 3.54907352e-04,
#        7.04084953e-05, 6.97371573e-05, 3.48806711e-05, 2.67760703e-04,
#        6.97371573e-05, 5.70775217e-05, 4.93248025e-05, 4.45963003e-05,
#        2.96446404e-05, 1.30992879e-04, 7.00768853e-05, 3.48685787e-05,
#        1.33156010e-04, 3.48625324e-05, 3.48685787e-05, 2.95902244e-05,
#        3.05585922e-05, 2.29642841e-05, 2.72227401e-04, 5.40127792e-05,
#        3.48806711e-05, 1.41690741e-02, 4.43853366e-05, 4.45183535e-05,
#        2.17420047e-04, 1.10029114e-04, 2.95902244e-05, 3.48685787e-05,
#        3.48685787e-05, 4.11304418e-05])

# %%
np.sum(np.array(bv.a) > m + 3*sigma2)
# Out:
# 554

# %%
np.quantile(np.array(bv.a),3/4) # quantile 3/4
# Out:
# 1.7692494253037017e-08

# %%
np.quantile(np.array(bv.a),1/4) # quantile 1/4
# Out:
# 0.0

# %%
eiq = np.quantile(np.array(bv.a),3/4) - np.quantile(np.array(bv.a),1/4)

# %%
treshold  = np.quantile(np.array(bv.a),3/4) + 1.5*eiq

# %%
outliers = np.array(bv.a)[np.array(bv.a) > treshold]

# %%
len(outliers)
# Out:
# 2739

# %%
import matplotlib.pyplot as plt 
plt.boxplot(np.array(bv.a))
plt.show()

# %%
plt.hist(bv.a)
# Out:
# (array([1.2859e+04, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  PropertyArray([0.        , 0.0068778 , 0.0137556 , 0.02063339, 0.02751119,
#                 0.03438899, 0.04126679, 0.04814458, 0.05502238, 0.06190018,
#                 0.06877798]),
#  <a list of 10 Patch objects>)

# %%
ew.a # On récupère les poids
# Out:
# PropertyArray([1.11955450e+17, 1.00000000e+00, 1.00000000e+00, ...,
#                1.36093416e+18, 1.24358780e+18, 2.83827838e+18])

# %%
transactionsweights = ew.a

# %%
ewq34 = np.quantile(np.array(ew.a),3/4) # quantile 3/4

# %%
ewq14 = np.quantile(np.array(ew.a),1/4) # quantile 1/4

# %%
ewiq = ewq34 - ewq14

# %%
len(transactionsweights[transactionsweights > 1.5*ewiq])
# Out:
# 11781

# %%
plt.boxplot(np.array(transactionsweights))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f5be0155f28>,
#   <matplotlib.lines.Line2D at 0x7f5be00de2e8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f5be00de630>,
#   <matplotlib.lines.Line2D at 0x7f5be00de978>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f5be0155dd8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f5be00decc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5be00ea048>],
#  'means': []}

# %%
transactionsweights[transactionsweights > 1.5*ewiq] 
# On va partir du principe que les adresses qui ont de gros volumes de transaction + une fréquence importante + 
# une centralité forte sont des outliers
# Out:
# PropertyArray([9.99937000e+18, 7.02371600e+18, 4.95518193e+18, ...,
#                5.75967840e+18, 4.12631593e+18, 5.09993187e+18])

# %%
m_ew, std = edge_average(g,ew) # average and std

# %%
np.sum(np.array(ew.a) > m_ew + 3*std)
# Out:
# 2833

# %%
plt.hist(np.array(ew.a))
# Out:
# (array([5.4875e+04, 2.2000e+01, 6.0000e+00, 2.0000e+00, 5.0000e+00,
#         2.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([0.000000e+00, 1.169950e+22, 2.339900e+22, 3.509850e+22,
#         4.679800e+22, 5.849750e+22, 7.019700e+22, 8.189650e+22,
#         9.359600e+22, 1.052955e+23, 1.169950e+23]),
#  <a list of 10 Patch objects>)

# %%
g.edges
# Out:
# <bound method Graph.edges of <Graph object, directed, with 12862 vertices and 54914 edges at 0x7f5be5909908>>

# %%
2833/54914
# Out:
# 0.05158975853152201

# %%
para = label_parallel_edges(g)

# %%
para.a
# Out:
# PropertyArray([ 0,  0,  1, ...,  8,  7, 18], dtype=int32)

# %%
np.max(para.a)
# Out:
# PropertyArray(3097, dtype=int32)

# %%
np.argmax([para.a == 3097])
# Out:
# 54496

# %%
g.get_edges()
# Out:
# array([[    0,  1012, 32522],
#        [    2,  3959, 11066],
#        [    3,  2140,  4681],
#        ...,
#        [12859,  2638, 39381],
#        [12859,  2638, 51008],
#        [12860,  1012, 50076]], dtype=uint64)

# %%
df_edges = pd.DataFrame(g.get_edges(),columns=['from','to','index'])

# %%
df_edges[df_edges['index'] == 54496]
# Out:
#        from    to  index
# 37500  5075  1648  54496

# %%
data2.loc[( data2['from_address'] == 5075 ) & ( data2['to_address'] == 1648 )]
# Out:
#        from_address  to_address         value
# 50             5075        1648  1.620161e+17
# 51             5075        1648  1.550496e+17
# 52             5075        1648  1.621251e+17
# 53             5075        1648  1.563533e+17
# 54             5075        1648  1.566986e+17
# 55             5075        1648  1.812749e+17
# 87             5075        1648  1.536670e+17
# 89             5075        1648  1.537074e+17
# 116            5075        1648  1.545639e+17
# 117            5075        1648  1.553569e+17
# 118            5075        1648  1.576880e+17
# 119            5075        1648  1.564262e+17
# 120            5075        1648  1.680000e+17
# 121            5075        1648  1.573503e+17
# 123            5075        1648  1.570922e+17
# 124            5075        1648  1.565338e+17
# 125            5075        1648  1.540025e+17
# 126            5075        1648  1.713774e+17
# 209            5075        1648  1.526436e+17
# 211            5075        1648  1.520735e+17
# 312            5075        1648  1.521282e+17
# 314            5075        1648  1.522562e+17
# 369            5075        1648  1.634387e+17
# 371            5075        1648  1.567522e+17
# 380            5075        1648  1.517982e+17
# 382            5075        1648  1.522853e+17
# 384            5075        1648  1.553044e+17
# 386            5075        1648  1.819104e+17
# 388            5075        1648  2.312436e+17
# 390            5075        1648  1.555831e+17
# ...             ...         ...           ...
# 54379          5075        1648  2.195562e+17
# 54464          5075        1648  3.339714e+17
# 54465          5075        1648  2.368488e+17
# 54466          5075        1648  2.017828e+17
# 54467          5075        1648  2.062613e+17
# 54468          5075        1648  2.045605e+17
# 54472          5075        1648  2.033165e+17
# 54473          5075        1648  2.061066e+17
# 54475          5075        1648  2.018988e+17
# 54476          5075        1648  1.939737e+17
# 54477          5075        1648  1.975252e+17
# 54478          5075        1648  2.179248e+17
# 54479          5075        1648  2.360939e+17
# 54480          5075        1648  2.176866e+17
# 54481          5075        1648  2.329145e+17
# 54482          5075        1648  3.712438e+17
# 54483          5075        1648  2.066078e+17
# 54484          5075        1648  2.045833e+17
# 54485          5075        1648  1.995206e+17
# 54486          5075        1648  3.824882e+17
# 54487          5075        1648  1.949346e+17
# 54488          5075        1648  2.162690e+17
# 54489          5075        1648  1.990577e+17
# 54490          5075        1648  2.049364e+17
# 54491          5075        1648  1.938444e+17
# 54492          5075        1648  1.979689e+17
# 54493          5075        1648  2.051589e+17
# 54494          5075        1648  2.242702e+17
# 54495          5075        1648  4.059830e+17
# 54496          5075        1648  1.951332e+17
#
# [3098 rows x 3 columns]

# %%
Encoder.inverse_transform(df_edges[df_edges['index'] == 5075]['from'])
# Out:
# array(['0x9f6b5894fccc07a8339b5903d5a3f4b4740ad10b'], dtype=object)

# %%
Encoder.inverse_transform(df_edges[df_edges['index'] == 1648]['to'])
# Out:
# array(['0xe50378b2e41944696ab0c2ffe93e98f2c42b3de8'], dtype=object)

# %%
g.get_in_degrees([1648],eweight=ew) # nombre de degrés entrants
# Out:
# array([6.0690082e+20])

# %%
g.get_edges().shape
# Out:
# (54914, 3)

# %%
graph_draw(g)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f5be5909908, at 0x7f5c2dbfe4a8>

# %%
g.list_properties()
# Out:
# edge_weight    (edge)    (type: double)

# %%
# Ici on a une matrice constituée de depart / arrivée / id
g.get_edges()
# Out:
# array([[    0,  1012, 32522],
#        [    2,  3959, 11066],
#        [    3,  2140,  4681],
#        ...,
#        [12859,  2638, 39381],
#        [12859,  2638, 51008],
#        [12860,  1012, 50076]], dtype=uint64)

# %%
# On compare au tableau des transactions

data2[data2['from_address'] == 12859]
# Out:
#        from_address  to_address         value
# 1797          12859        2638  5.179937e+19
# 39381         12859        2638  8.138879e+19
# 51008         12859        2638  1.538916e+20

# %%
# On compare au tableau des transactions

data2[data2['from_address'] == 0]
# Out:
#        from_address  to_address         value
# 32522             0        1012  1.664428e+20

# %%
# On compare au tableau des transactions

data2[data2['from_address'] == 2]
# Out:
#        from_address  to_address         value
# 11066             2        3959  5.000000e+18

# %% [markdown]
# # Création de fonctions d'import

# %%
import glob

def aggregate_csv():
    """
    Concatene les csv présents dans le répertoire courant, 
    Renvoie un pandas DF résultant de la concaténation
    
    """
    extension = 'csv'
    all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
    combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
    combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
    return(combined_csv)

# %%
full_data = aggregate_csv()

# %%
full_data.head()
# Out:
#                                                 hash  nonce  \
# 0  0xba048f59c055470fed2668d2d040879ab5ef5dfc106c...     42
# 1  0x0a1807644cef7ea7eca30c075512b1136c28b24ac538...  37665
# 2  0x4d1ebaeddfdf5db17a83753003f6eaa50841b599ef15...  37666
# 3  0xac1baec5b7ce60fa5b7afcb1f362e41c5cb529384e69...     14
# 4  0xda255e01a213a47f3454e085681198f48b61ea947ab4...    138
#
#                                           block_hash  block_number  \
# 0  0xcb16bbb2b7b593f506369f0174355254485960fba2cd...       1160100
# 1  0x62ee818f0b2b3047bd725317e820d83f0f5c5b9971b1...       1160101
# 2  0x62ee818f0b2b3047bd725317e820d83f0f5c5b9971b1...       1160101
# 3  0x40fc1e112e67eb5ad1cef2517dcce281fd43d18349d9...       1160104
# 4  0x40fc1e112e67eb5ad1cef2517dcce281fd43d18349d9...       1160104
#
#    transaction_index                                from_address  \
# 0                  0  0xc5698e5ed169e2ff546455c0431543bc641fdb20
# 1                  0  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 2                  1  0xc400b9d93a23b0be5d41ab337ad605988aef8463
# 3                  0  0x1431354497e6e11e24ec3fe9a76d4f7897e2a712
# 4                  1  0x4eb44a2d45370a8fe762040447112a6ce42ca6a2
#
#                                    to_address                value     gas  \
# 0  0x1699333a4e46093e15a94b4a213b88eb8a963834   111955450000000000   21000
# 1  0x9af09991ad63814e53ffc1bccf213ee74027608b                    1  300000
# 2  0x9af09991ad63814e53ffc1bccf213ee74027608b                    1  300000
# 3  0x32be343b94f860124dc4fee278fdcbd38c102d88  9999370000000000000   21000
# 4  0x32be343b94f860124dc4fee278fdcbd38c102d88  7023716000000000000   21000
#
#      gas_price                                              input
# 0  50000000000                                                 0x
# 1  52000000000  0x3ed4867900000000000000000000000036c425e72bbc...
# 2  52000000000  0x3ed48679000000000000000000000000490c0dd13bfe...
# 3  30000000000                                                 0x
# 4  30000000000                                                 0x

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import LabelEncoder




def format_as_tgraph(data):
    """
    Formatage d'un pandas DF en un pandas DF adapté
    à un import en graphe de transactions: 
    
    Renvoie un pandas DF dans un format adapté a un import graphique
    
    """
    
    # On transforme les addresses en str pour éviter les ennuis
    data[['from_address', 'to_address']] = data[['from_address', 'to_address']].astype(str)

    
    # On concatene les addresses pour éviter les doublons 
    
    full_addresses = np.append(data['from_address'].values,data['to_address'].values)
    
    
    # Encodage des addresses sur la liste ENTIERE des addresses 
    Encoder = LabelEncoder()
    Encoder.fit(full_addresses) #Apprend sur les addresses 

    new_from = Encoder.transform(data['from_address']) # On transforme
    new_to = Encoder.transform(data['to_address'])     # On transforme
    
    
    # Remplacement des colonnes par les colonnes ainsi encodées
    data['from_address'] = new_from
    data['to_address'] = new_to
    
    # On transforme la colonne value en float
    data[['value']] = data[['value']].astype(float)
    
    
    return(data)

# %%
full_data_graph = format_as_tgraph(full_data)

# %%
full_data_graph.head()
# Out:
#                                                 hash  nonce  \
# 0  0xba048f59c055470fed2668d2d040879ab5ef5dfc106c...     42
# 1  0x0a1807644cef7ea7eca30c075512b1136c28b24ac538...  37665
# 2  0x4d1ebaeddfdf5db17a83753003f6eaa50841b599ef15...  37666
# 3  0xac1baec5b7ce60fa5b7afcb1f362e41c5cb529384e69...     14
# 4  0xda255e01a213a47f3454e085681198f48b61ea947ab4...    138
#
#                                           block_hash  block_number  \
# 0  0xcb16bbb2b7b593f506369f0174355254485960fba2cd...       1160100
# 1  0x62ee818f0b2b3047bd725317e820d83f0f5c5b9971b1...       1160101
# 2  0x62ee818f0b2b3047bd725317e820d83f0f5c5b9971b1...       1160101
# 3  0x40fc1e112e67eb5ad1cef2517dcce281fd43d18349d9...       1160104
# 4  0x40fc1e112e67eb5ad1cef2517dcce281fd43d18349d9...       1160104
#
#    transaction_index  from_address  to_address         value     gas  \
# 0                  0         39951        4629  1.119554e+17   21000
# 1                  0         39645       31330  1.000000e+00  300000
# 2                  1         39645       31330  1.000000e+00  300000
# 3                  0          4181       10179  9.999370e+18   21000
# 4                  1         15919       10179  7.023716e+18   21000
#
#      gas_price                                              input
# 0  50000000000                                                 0x
# 1  52000000000  0x3ed4867900000000000000000000000036c425e72bbc...
# 2  52000000000  0x3ed48679000000000000000000000000490c0dd13bfe...
# 3  30000000000                                                 0x
# 4  30000000000                                                 0x

# %%
from graph_tool.all import *


def create_graph_obj(data):
    """
    Prend un pandas DF formaté correctement en transaction graph
    Crée et renvoie un objet graph-tool sur lequel on peut travailler
    
    """
    
    # Création du graphe vide
    g = Graph(directed=True) 

    # Ajout des arêtes suivant le np.array
    vmap = g.add_edge_list(data[['from_address','to_address']].values)

    # Ajout des edge weights 
    ew = g.new_edge_property("double")
    ew.a = data['value'].values
    g.ep['edge_weight'] = ew
    
    return(g)

# %%
g = create_graph_obj(full_data_graph)

# %%
graph_draw(g)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f0bbd9733c8, at 0x7f0c26c2cef0>

# %%
weights = g.edge_properties['edge_weight']

# %%
pos = sfdp_layout(g,eweight=weights)
graph_draw(g,pos=pos)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f0bbd9733c8, at 0x7f0bbf03df98>

# %%
adj_m = adjacency(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-180faf7b49e0> in <module>
# ----> 1 adj_m = adjacency(g)
#
# NameError: name 'adjacency' is not defined

# %%
degs = adj_m.sum(axis=0)

# %%
v_number = np.max(g.get_vertices())

# %%
deg_moy = np.sum(degs)/v_number

# %%
deg_moy
# Out:
# 16.46578947368421

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-48ab7f91165d> in <module>
# ----> 1 degs
#
# NameError: name 'degs' is not defined

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
g.get_vertices()
# Out:
# array([    0,     1,     2, ..., 51678, 51679, 51680], dtype=uint64)

# %%
g.get_edges()
# Out:
# array([[     1,   3750,  32522],
#        [     1,   3750,  87436],
#        [     1,   3750, 142350],
#        ...,
#        [ 51679,   4010, 239144],
#        [ 51679,   4010, 396968],
#        [ 51679,   4010, 554792]], dtype=uint64)

# %%
np.unique(np.append(full_data_graph['from_address'].values,full_data_graph['to_address'].values))
# Out:
# array([    0,     1,     2, ..., 51678, 51679, 51680])

# %%
len(vertex_hist(g, deg='in', bins=[0, 1], float_count=True)[0])
# Out:
# 43456

# %%
plt.hist(vertex_hist(g, deg='in', bins=[0, 1], float_count=True)[0])
# Out:
# (array([4.345e+04, 2.000e+00, 0.000e+00, 3.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([    0. ,  2028.7,  4057.4,  6086.1,  8114.8, 10143.5, 12172.2,
#         14200.9, 16229.6, 18258.3, 20287. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(vertex_hist(g, deg='out', bins=[0, 1], float_count=True)[0])
# Out:
# (array([7.2246e+04, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([    0. ,  1905.7,  3811.4,  5717.1,  7622.8,  9528.5, 11434.2,
#         13339.9, 15245.6, 17151.3, 19057. ]),
#  <a list of 10 Patch objects>)

# %%
edge_average(g,g.ep['edge_weight'])
# Out:
# (1.269410600649223e+20, 2.9361059026822876e+18)

# %%
vertex_hist(g,'in',bins=[0,1])
# Out:
# [array([6.602e+03, 0.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#         1.000e+00]),
#  array([    0,     1,     2, ..., 43454, 43455, 43456], dtype=uint64)]
