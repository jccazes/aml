# %%
import graph_tool as gt

# %%
from graph_tool.collection import data

# %%
from graph_tool.all import *

# %%
g = data["celegansneural"]

# %%
g
# Out:
# <Graph object, directed, with 297 vertices and 2359 edges at 0x7f6e44190eb8>

# %%
state = minimize_nested_blockmodel_dl(g)

# %%
state.draw()
# Out:
# (<PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f6e44190eb8, at 0x7f6e33eadc18>,
#  <Graph object, directed, with 314 vertices and 313 edges at 0x7f6e33ec1da0>,
#  <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f6e33ec1da0, at 0x7f6e33ec1048>)

# %%
state.print_summary
# Out:
# <bound method NestedBlockState.print_summary of <NestedBlockState object, with base <BlockState object with 12 blocks (12 nonempty), degree-corrected, for graph <Graph object, directed, with 297 vertices and 2359 edges at 0x7f6e44190eb8>, at 0x7f6e33ea5ef0>, and 3 levels of sizes [(297, 12), (12, 4), (4, 1)] at 0x7f6e33eadc88>>

# %%
state.get_bs()
# Out:
# [PropertyArray([ 0,  0,  1,  1,  1,  0,  2,  2,  0,  0,  3,  0,  1,  2,  0,
#                  2,  0,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  3,  2,
#                  2,  2,  2,  2,  2,  2,  2,  2,  2,  0,  2,  2,  4,  2,  5,
#                  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#                  2,  2,  2,  0,  2,  0,  2,  0,  2,  2,  2,  2,  0,  2,  2,
#                  2,  2,  2,  2,  2,  4,  2,  2,  2,  1,  0,  1,  0,  2,  2,
#                  2,  2,  0,  0,  2,  6,  4,  7,  6,  0,  0,  0,  0,  0,  0,
#                  0,  0,  3,  0,  0,  0,  6,  0,  3,  0,  3,  0,  1,  1,  6,
#                  0,  0,  3,  8,  3,  1,  3,  3,  3,  0,  0,  0,  0,  8,  3,
#                  3,  3,  6,  3,  3,  3,  3,  8,  3,  3,  8,  8,  3,  8,  8,
#                  8,  9,  7,  7,  9,  9,  9,  9,  9,  9,  9,  9,  9,  9, 11,
#                  7,  7,  7,  9,  9,  4,  4,  1,  9,  4,  9,  7,  4,  9,  9,
#                  9,  9,  9,  7,  4,  4,  4,  8,  9, 10,  4,  8,  9,  8,  4,
#                  8, 10, 10,  8,  8, 10,  0,  8,  6,  4,  8,  4,  4,  3,  2,
#                  0,  0,  0,  6,  0,  0,  0,  4,  6, 10,  4,  7,  0,  0,  6,
#                  6,  4,  7,  4,  4, 10, 10,  9, 10, 11,  0,  2, 10, 10,  0,
#                  0,  0,  4,  4, 10, 10, 11,  4,  4,  7,  7,  7,  4,  7,  7,
#                  4,  4,  4,  4,  4,  4,  4,  9,  9,  9,  9,  9,  9, 11, 11,
#                 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 10, 10,  5,
#                  9,  9,  9,  9,  9,  9,  9,  9,  9,  9,  4,  4],
#                dtype=int32),
#  PropertyArray([0, 1, 0, 0, 2, 3, 0, 3, 2, 3, 3, 3], dtype=int32),
#  PropertyArray([0, 0, 0, 0], dtype=int32)]

# %%
state.print_summary()
# Out:
# l: 0, N: 297, B: 12
# l: 1, N: 12, B: 4
# l: 2, N: 4, B: 1
