# %% [markdown]
# ### Packages

# %%
import os 
import import_ipynb
from time import sleep
# Working Directory
os.chdir("../data")

# Importing notebooks 
from Import_data import *
from Recup_scams_ex import *
# Out:
# importing Jupyter notebook from Recup_scams_ex.ipynb

# %% [markdown]
# # Idées premières

# %% [markdown]
# On dispose de données labellisées comme étant des "scams", des arnaques.
# Ce sont essentiellement des adresses ETH, dont il faut regarder le comportement.
# Quels features faire sortir de ces adresses, qui caractériseraient les comportements suspects?
#
# Une fois un modèle de caractérisation d'adresses/contrats suspects choisi, on pourra tenter d'associer les adresses entre elles.

# %% [markdown]
# ## Caractérisation d'une adresse/contrat suspect

# %% [markdown]
# 1) Un temps d'inactivté, puis un "boom" d'activité peut-être considéré comme un comportement suspect. On part du principe qu'une adresse ETH est en règle générale idle.
#
# 2) Un flux de transactions parallèles et/ou de même montant vers une même ou différentes adresses.
#
# 3) Un flux de transactions soudain ("établir un rapport, une proportion"?) qui vide le compte d'un seul coup? Eventuellement un outlier sur la proportion quantité d'ETH (in ou out) / temps en h.
#
# 4) Des transactions vers des oeuvres de charité suspicieuses.
#
# 5) Une distance vers un exchange assez court, mais pas direct? (Il faut suivre les transactions qui émanent d'une adresse vers une autre ou plusieurs adresses, de même montant ou de montant divisé, qui mènent à un exchange.)
#
# 6) On peut s'attendre a des envois d'ETH entre les adresses scams (on peut tenter de compter ces nombres de transactions en communauté) et des petits (ou gros d'ailleurs) envois vers des adresses non suspectes, peut-être des mules (les compter?). Le regroupement de portefeuilles sera traité en seconde part.
#
# 7) Eventuellement, regarder les transactions qui entrent dans les exchanges, de montants assez elevées?
#
# 8) Peut etre qu'il se passe aussi un grand nombre de transactions "à blanc"? Petits montants, adresses qui semblent pas liées? IL FAUT REGARDER LES GROS MONTANTS. EPS-Voisinage
#
# IL FAUT REGARDER LE DERNIER NOEUD AVANT L EXCHANGE, CE SERA UN PORTEFEUILLE CONTROLE
#
# 9) Obfuscation par l'utilisation de token?
#
# PS: Certains gros utilisateurs font du margin trading, prendre cela en compte par rapport à l'activité des adresses
# En gros, ils passent de beaucoup d'ETH, a tres peu d'un coup. Ou bien encore quand il n'y a que des transactions qui viennent d'exchanges.

# %% [markdown]
# ## Temps

# %% [markdown]
# Gestion de la composante temporelle:
# On n'a accès qu'aux adresses si les transactions ont lieu.
# Il faut aller chercher suffisamment profondément dans les blocks, afin d'avoir un historique large.

# %% [markdown]
# De plus, les transactions se suivent, il faut trouver un moyen de prendre ca en compte.

# %% [markdown]
# # Feature engineering

# %%
scam_data = get_ethscam_data()

# %%
scam_data2 = parse_all_ethscan()

# %%
scam_data2.head()
# Out:
#                                     addresses          precision  \
# 0  0xdf9191889649c442836ef55de5036a7b694115b6  Fake_Phishing1431
# 1  0xf6884686a999f5ae6c1af03db92bab9c6d7dc8de    Coinrail Hacker
# 2  0xf2401fa52bcaacfdc67fd7f2b8983ddd15092fa9  Fake_Phishing2753
# 3  0x7F183Cce61eFcABb8d2eb1340f2A94C5EB1Bf8e5   Fake_Phishing618
# 4  0x5411a839780e8b7aceb9353056e9302b81c7f63b  Fake_Phishing2761
#
#         balance  txn
# 0  11371.001874   39
# 1   7446.134011   22
# 2   1164.747959   25
# 3   1084.427728    5
# 4    646.977000    1

# %%
scam_data
# Out:
#                0x2b065809f6ec6df32878bcd26711a0e2bcf59c26  \
# addresses    [0x2b065809f6ec6df32878bcd26711a0e2bcf59c26]
# category                                         Phishing
# coin                                                  ETH
# description           slackbot / reddit dms. did not 404.
# id                                                     77
# ip                                                    NaN
# name                                 myetherwallet.com.de
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                 MyEtherWallet
# url                           http://myetherwallet.com.de
#
#             0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f3c867664e43a626d878c0  \
# addresses    [0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f...
# category                                              Phishing
# coin                                                       ETH
# description                          did not 404.,MEW Deployed
# id                                                          81
# ip                                              69.172.201.153
# name                                          myetherwallet.us
# nameservers  [ns2.uniregistrymarket.link, ns1.uniregistryma...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                      MyEtherWallet
# url                                    http://myetherwallet.us
#
#             0x2dfe2e0522cc1f050edcc7a05213bb55bbb36884ec9468fc39eccc013c65b5e4  \
# addresses    [0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f...
# category                                              Phishing
# coin                                                       ETH
# description                          did not 404.,MEW Deployed
# id                                                          81
# ip                                              69.172.201.153
# name                                          myetherwallet.us
# nameservers  [ns2.uniregistrymarket.link, ns1.uniregistryma...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                      MyEtherWallet
# url                                    http://myetherwallet.us
#
#             0x1c6e3348a7ea72ffe6a384e51bd1f36ac1bcb4264f461889a318a3bb2251bf19  \
# addresses    [0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f...
# category                                              Phishing
# coin                                                       ETH
# description                          did not 404.,MEW Deployed
# id                                                          81
# ip                                              69.172.201.153
# name                                          myetherwallet.us
# nameservers  [ns2.uniregistrymarket.link, ns1.uniregistryma...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                      MyEtherWallet
# url                                    http://myetherwallet.us
#
#                0xd0cc2b24980cbcca47ef755da88b220a82291407  \
# addresses    [0xd0cc2b24980cbcca47ef755da88b220a82291407]
# category                                         Phishing
# coin                                                  ETH
# description                                           NaN
# id                                                      2
# ip                                                    NaN
# name                                    myelherwallel.com
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                 MyEtherWallet
# url                              http://myelherwallel.com
#
#                0xaa1886de3f70a3ef502ea1379a311c5b4e05f3fd  \
# addresses    [0xaa1886de3f70a3ef502ea1379a311c5b4e05f3fd]
# category                                         Phishing
# coin                                                  ETH
# description                                     Insertion
# id                                                    360
# ip                                                    NaN
# name                                   myaetherwallet.com
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                 MyEtherWallet
# url                             http://myaetherwallet.com
#
#                0x240e125c20a4cc84bd6e7f8d1fd07aff4c06d43d  \
# addresses    [0x240e125c20a4cc84bd6e7f8d1fd07aff4c06d43d]
# category                                         Fake ICO
# coin                                                  ETH
# description                fake ICO site w/ fake address.
# id                                                     31
# ip                                                    NaN
# name                                       district-0x.io
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                    district0x
# url                                 http://district-0x.io
#
#                0x1d60606d8a09b5015d773a80b0c660bb8d91809c  \
# addresses    [0x1d60606d8a09b5015d773a80b0c660bb8d91809c]
# category                                         Phishing
# coin                                                  ETH
# description           slackbot / reddit dms. did not 404.
# id                                                     88
# ip                                                    NaN
# name                                 myetherwallet.com.cm
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                 MyEtherWallet
# url                           http://myetherwallet.com.cm
#
#                0xadf5b0c2103598fb66a61714152f1d1717d49fe0  \
# addresses    [0xadf5b0c2103598fb66a61714152f1d1717d49fe0]
# category                                         Fake ICO
# coin                                                  ETH
# description                                           NaN
# id                                                     47
# ip                                                    NaN
# name                                 contribute-status.im
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                        Status
# url                           http://contribute-status.im
#
#                     0xba83e9ce38b10522e3d6061a12779b7526839eda  \
# addresses    [0xba83e9ce38b10522e3d6061a12779b7526839eda, 0...
# category                                              Phishing
# coin                                                       ETH
# description                     scambot phishers. did not 404.
# id                                                          90
# ip                                               31.170.160.61
# name                                        myetherwallet.tech
# nameservers  [ns3.hostinger.ru, ns1.hostinger.ru, ns2.hosti...
# reporter                                              MyCrypto
# status                                                  Active
# subcategory                                      MyEtherWallet
# url                                  http://myetherwallet.tech
#
#                                    ...                          \
# addresses                          ...
# category                           ...
# coin                               ...
# description                        ...
# id                                 ...
# ip                                 ...
# name                               ...
# nameservers                        ...
# reporter                           ...
# status                             ...
# subcategory                        ...
# url                                ...
#
#                     0x8bba1a1c5e9f72c2ce97a240a7878dd4ae803b61  \
# addresses    [1pgkghxgczpbaazu4kfarnmqrnsr3izgwi, 0x8bba1a1...
# category                                              Scamming
# coin                                                       ETH
# description                            Trust trading scam site
# id                                                        6612
# ip                                              185.62.190.207
# name                                            dex-launch.com
# nameservers           [ns2.blazingfast.io, ns1.blazingfast.io]
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                      Trust-Trading
# url                                      http://dex-launch.com
#
#                             1gj9tymgjcfsnjprkdcaugemewix2ysbdl  \
# addresses    [1gj9tymgjcfsnjprkdcaugemewix2ysbdl, 0x0bb4251...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6604
# ip                                                 217.23.6.10
# name                                                   gdax.us
# nameservers  [c358ea2d.bitcoin-dns.hosting, 1a7ea920.bitcoi...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                             http://gdax.us
#
#                     0x0bb4251b8c5e8acb27d6809d77a10aa1cacc5144  \
# addresses    [1gj9tymgjcfsnjprkdcaugemewix2ysbdl, 0x0bb4251...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6604
# ip                                                 217.23.6.10
# name                                                   gdax.us
# nameservers  [c358ea2d.bitcoin-dns.hosting, 1a7ea920.bitcoi...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                             http://gdax.us
#
#                     qzh7l8neh3v868uzu74qpyat4gjz2rdv0yhjktqcp2  \
# addresses    [1gj9tymgjcfsnjprkdcaugemewix2ysbdl, 0x0bb4251...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6604
# ip                                                 217.23.6.10
# name                                                   gdax.us
# nameservers  [c358ea2d.bitcoin-dns.hosting, 1a7ea920.bitcoi...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                             http://gdax.us
#
#                             1lptqoigtdmbrlb76g5w7ceja4wshpag9z  \
# addresses    [1lptqoigtdmbrlb76g5w7ceja4wshpag9z, 0x84a8e20...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6605
# ip                                                 217.23.6.10
# name                                            hillstrade.net
# nameservers  [dns1.registrar-servers.com, dns2.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://hillstrade.net
#
#                     0x84a8e201cfce8a10b1e721e1940a78a3326b7c97  \
# addresses    [1lptqoigtdmbrlb76g5w7ceja4wshpag9z, 0x84a8e20...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6605
# ip                                                 217.23.6.10
# name                                            hillstrade.net
# nameservers  [dns1.registrar-servers.com, dns2.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://hillstrade.net
#
#                     qpdjfyy89utdz5ky34exk3s98c9h4ahtwyjgdr9dze  \
# addresses    [1lptqoigtdmbrlb76g5w7ceja4wshpag9z, 0x84a8e20...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6605
# ip                                                 217.23.6.10
# name                                            hillstrade.net
# nameservers  [dns1.registrar-servers.com, dns2.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://hillstrade.net
#
#                             1mx2sjhokgbrnrukj8nsqzur5vlorulhf7  \
# addresses    x2sjhokgbrnrukj8nsqzur5vlorulhf7, 0x8f0e5ef...
# category                                              Scamming
# coin                                                       ETH
# description                                      Fake exchange
# id                                                        6548
# ip                                                 217.23.6.10
# name                                            your-btc.co.uk
# nameservers  [dns2.registrar-servers.com, dns1.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://your-btc.co.uk
#
#                     0x8f0e5ef93838ffb9bc2c5afb34c32f55ea97a932  \
# addresses    x2sjhokgbrnrukj8nsqzur5vlorulhf7, 0x8f0e5ef...
# category                                              Scamming
# coin                                                       ETH
# description                                      Fake exchange
# id                                                        6548
# ip                                                 217.23.6.10
# name                                            your-btc.co.uk
# nameservers  [dns2.registrar-servers.com, dns1.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://your-btc.co.uk
#
#                     qzuqzn8y2726k2pwx3767zmja9m9wdh5wyukklr6kf
# addresses    x2sjhokgbrnrukj8nsqzur5vlorulhf7, 0x8f0e5ef...
# category                                              Scamming
# coin                                                       ETH
# description                                      Fake exchange
# id                                                        6548
# ip                                                 217.23.6.10
# name                                            your-btc.co.uk
# nameservers  [dns2.registrar-servers.com, dns1.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://your-btc.co.uk
#
# [12 rows x 2133 columns]

# %%
# Indices des adresses scams uniquement liées a l'ETH
ind = scam_data.iloc[2] == "ETH"
ind = np.argwhere(ind)[:,0]
ind
# Out:
# array([   0,    1,    2, ..., 2130, 2131, 2132])

# %%
df = pd.DataFrame()

# %%
# On récupère l'ensemble du tableau filtré par indices ETH
scam_data.iloc[:,ind]
# Out:
#                0x2b065809f6ec6df32878bcd26711a0e2bcf59c26  \
# addresses    [0x2b065809f6ec6df32878bcd26711a0e2bcf59c26]
# category                                         Phishing
# coin                                                  ETH
# description           slackbot / reddit dms. did not 404.
# id                                                     77
# ip                                                    NaN
# name                                 myetherwallet.com.de
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                 MyEtherWallet
# url                           http://myetherwallet.com.de
#
#             0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f3c867664e43a626d878c0  \
# addresses    [0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f...
# category                                              Phishing
# coin                                                       ETH
# description                          did not 404.,MEW Deployed
# id                                                          81
# ip                                              69.172.201.153
# name                                          myetherwallet.us
# nameservers  [ns2.uniregistrymarket.link, ns1.uniregistryma...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                      MyEtherWallet
# url                                    http://myetherwallet.us
#
#             0x2dfe2e0522cc1f050edcc7a05213bb55bbb36884ec9468fc39eccc013c65b5e4  \
# addresses    [0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f...
# category                                              Phishing
# coin                                                       ETH
# description                          did not 404.,MEW Deployed
# id                                                          81
# ip                                              69.172.201.153
# name                                          myetherwallet.us
# nameservers  [ns2.uniregistrymarket.link, ns1.uniregistryma...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                      MyEtherWallet
# url                                    http://myetherwallet.us
#
#             0x1c6e3348a7ea72ffe6a384e51bd1f36ac1bcb4264f461889a318a3bb2251bf19  \
# addresses    [0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f...
# category                                              Phishing
# coin                                                       ETH
# description                          did not 404.,MEW Deployed
# id                                                          81
# ip                                              69.172.201.153
# name                                          myetherwallet.us
# nameservers  [ns2.uniregistrymarket.link, ns1.uniregistryma...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                      MyEtherWallet
# url                                    http://myetherwallet.us
#
#                0xd0cc2b24980cbcca47ef755da88b220a82291407  \
# addresses    [0xd0cc2b24980cbcca47ef755da88b220a82291407]
# category                                         Phishing
# coin                                                  ETH
# description                                           NaN
# id                                                      2
# ip                                                    NaN
# name                                    myelherwallel.com
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                 MyEtherWallet
# url                              http://myelherwallel.com
#
#                0xaa1886de3f70a3ef502ea1379a311c5b4e05f3fd  \
# addresses    [0xaa1886de3f70a3ef502ea1379a311c5b4e05f3fd]
# category                                         Phishing
# coin                                                  ETH
# description                                     Insertion
# id                                                    360
# ip                                                    NaN
# name                                   myaetherwallet.com
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                 MyEtherWallet
# url                             http://myaetherwallet.com
#
#                0x240e125c20a4cc84bd6e7f8d1fd07aff4c06d43d  \
# addresses    [0x240e125c20a4cc84bd6e7f8d1fd07aff4c06d43d]
# category                                         Fake ICO
# coin                                                  ETH
# description                fake ICO site w/ fake address.
# id                                                     31
# ip                                                    NaN
# name                                       district-0x.io
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                    district0x
# url                                 http://district-0x.io
#
#                0x1d60606d8a09b5015d773a80b0c660bb8d91809c  \
# addresses    [0x1d60606d8a09b5015d773a80b0c660bb8d91809c]
# category                                         Phishing
# coin                                                  ETH
# description           slackbot / reddit dms. did not 404.
# id                                                     88
# ip                                                    NaN
# name                                 myetherwallet.com.cm
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                 MyEtherWallet
# url                           http://myetherwallet.com.cm
#
#                0xadf5b0c2103598fb66a61714152f1d1717d49fe0  \
# addresses    [0xadf5b0c2103598fb66a61714152f1d1717d49fe0]
# category                                         Fake ICO
# coin                                                  ETH
# description                                           NaN
# id                                                     47
# ip                                                    NaN
# name                                 contribute-status.im
# nameservers                                           NaN
# reporter                                         MyCrypto
# status                                            Offline
# subcategory                                        Status
# url                           http://contribute-status.im
#
#                     0xba83e9ce38b10522e3d6061a12779b7526839eda  \
# addresses    [0xba83e9ce38b10522e3d6061a12779b7526839eda, 0...
# category                                              Phishing
# coin                                                       ETH
# description                     scambot phishers. did not 404.
# id                                                          90
# ip                                               31.170.160.61
# name                                        myetherwallet.tech
# nameservers  [ns3.hostinger.ru, ns1.hostinger.ru, ns2.hosti...
# reporter                                              MyCrypto
# status                                                  Active
# subcategory                                      MyEtherWallet
# url                                  http://myetherwallet.tech
#
#                                    ...                          \
# addresses                          ...
# category                           ...
# coin                               ...
# description                        ...
# id                                 ...
# ip                                 ...
# name                               ...
# nameservers                        ...
# reporter                           ...
# status                             ...
# subcategory                        ...
# url                                ...
#
#                     0x8bba1a1c5e9f72c2ce97a240a7878dd4ae803b61  \
# addresses    [1pgkghxgczpbaazu4kfarnmqrnsr3izgwi, 0x8bba1a1...
# category                                              Scamming
# coin                                                       ETH
# description                            Trust trading scam site
# id                                                        6612
# ip                                              185.62.190.207
# name                                            dex-launch.com
# nameservers           [ns2.blazingfast.io, ns1.blazingfast.io]
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                      Trust-Trading
# url                                      http://dex-launch.com
#
#                             1gj9tymgjcfsnjprkdcaugemewix2ysbdl  \
# addresses    [1gj9tymgjcfsnjprkdcaugemewix2ysbdl, 0x0bb4251...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6604
# ip                                                 217.23.6.10
# name                                                   gdax.us
# nameservers  [c358ea2d.bitcoin-dns.hosting, 1a7ea920.bitcoi...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                             http://gdax.us
#
#                     0x0bb4251b8c5e8acb27d6809d77a10aa1cacc5144  \
# addresses    [1gj9tymgjcfsnjprkdcaugemewix2ysbdl, 0x0bb4251...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6604
# ip                                                 217.23.6.10
# name                                                   gdax.us
# nameservers  [c358ea2d.bitcoin-dns.hosting, 1a7ea920.bitcoi...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                             http://gdax.us
#
#                     qzh7l8neh3v868uzu74qpyat4gjz2rdv0yhjktqcp2  \
# addresses    [1gj9tymgjcfsnjprkdcaugemewix2ysbdl, 0x0bb4251...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6604
# ip                                                 217.23.6.10
# name                                                   gdax.us
# nameservers  [c358ea2d.bitcoin-dns.hosting, 1a7ea920.bitcoi...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                             http://gdax.us
#
#                             1lptqoigtdmbrlb76g5w7ceja4wshpag9z  \
# addresses    [1lptqoigtdmbrlb76g5w7ceja4wshpag9z, 0x84a8e20...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6605
# ip                                                 217.23.6.10
# name                                            hillstrade.net
# nameservers  [dns1.registrar-servers.com, dns2.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://hillstrade.net
#
#                     0x84a8e201cfce8a10b1e721e1940a78a3326b7c97  \
# addresses    [1lptqoigtdmbrlb76g5w7ceja4wshpag9z, 0x84a8e20...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6605
# ip                                                 217.23.6.10
# name                                            hillstrade.net
# nameservers  [dns1.registrar-servers.com, dns2.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://hillstrade.net
#
#                     qpdjfyy89utdz5ky34exk3s98c9h4ahtwyjgdr9dze  \
# addresses    [1lptqoigtdmbrlb76g5w7ceja4wshpag9z, 0x84a8e20...
# category                                              Scamming
# coin                                                       ETH
# description             Fake exchange (same as your-btc.co.uk)
# id                                                        6605
# ip                                                 217.23.6.10
# name                                            hillstrade.net
# nameservers  [dns1.registrar-servers.com, dns2.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://hillstrade.net
#
#                             1mx2sjhokgbrnrukj8nsqzur5vlorulhf7  \
# addresses    x2sjhokgbrnrukj8nsqzur5vlorulhf7, 0x8f0e5ef...
# category                                              Scamming
# coin                                                       ETH
# description                                      Fake exchange
# id                                                        6548
# ip                                                 217.23.6.10
# name                                            your-btc.co.uk
# nameservers  [dns2.registrar-servers.com, dns1.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://your-btc.co.uk
#
#                     0x8f0e5ef93838ffb9bc2c5afb34c32f55ea97a932  \
# addresses    x2sjhokgbrnrukj8nsqzur5vlorulhf7, 0x8f0e5ef...
# category                                              Scamming
# coin                                                       ETH
# description                                      Fake exchange
# id                                                        6548
# ip                                                 217.23.6.10
# name                                            your-btc.co.uk
# nameservers  [dns2.registrar-servers.com, dns1.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://your-btc.co.uk
#
#                     qzuqzn8y2726k2pwx3767zmja9m9wdh5wyukklr6kf
# addresses    x2sjhokgbrnrukj8nsqzur5vlorulhf7, 0x8f0e5ef...
# category                                              Scamming
# coin                                                       ETH
# description                                      Fake exchange
# id                                                        6548
# ip                                                 217.23.6.10
# name                                            your-btc.co.uk
# nameservers  [dns2.registrar-servers.com, dns1.registrar-se...
# reporter                                              MyCrypto
# status                                                 Offline
# subcategory                                           Exchange
# url                                      http://your-btc.co.uk
#
# [12 rows x 2009 columns]

# %%
addresses = np.array(scam_data.iloc[:,ind].columns)

# %%
addresses
# Out:
# array(['0x2b065809f6ec6df32878bcd26711a0e2bcf59c26',
#        '0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f3c867664e43a626d878c0',
#        '0x2dfe2e0522cc1f050edcc7a05213bb55bbb36884ec9468fc39eccc013c65b5e4',
#        ..., '1mx2sjhokgbrnrukj8nsqzur5vlorulhf7',
#        '0x8f0e5ef93838ffb9bc2c5afb34c32f55ea97a932',
#        'qzuqzn8y2726k2pwx3767zmja9m9wdh5wyukklr6kf'], dtype=object)

# %%
prec1 = np.array(scam_data.iloc[1,ind])

# %%
prec1
# Out:
# array(['Phishing', 'Phishing', 'Phishing', ..., 'Scamming', 'Scamming',
#        'Scamming'], dtype=object)

# %%
prec2 = np.array(scam_data.iloc[6,ind])

# %%
prec2
# Out:
# array(['myetherwallet.com.de', 'myetherwallet.us', 'myetherwallet.us',
#        ..., 'your-btc.co.uk', 'your-btc.co.uk', 'your-btc.co.uk'],
#       dtype=object)

# %%
prec = []
for i,j in zip(prec1,prec2):
    prec.append(i+" "+j)
prec
# Out:
# ['Phishing myetherwallet.com.de',
#  'Phishing myetherwallet.us',
#  'Phishing myetherwallet.us',
#  'Phishing myetherwallet.us',
#  'Phishing myelherwallel.com',
#  'Phishing myaetherwallet.com',
#  'Fake ICO district-0x.io',
#  'Phishing myetherwallet.com.cm',
#  'Fake ICO contribute-status.im',
#  'Phishing myetherwallet.tech',
#  'Phishing myetherwallet.com.im',
#  'Phishing myetherwallet.com.im',
#  'Phishing ethereumchamber.net',
#  'Phishing unocoin.fund',
#  'Phishing numerai.tech',
#  'Phishing OmiseGO.com',
#  'Phishing OmiseGO.net',
#  'Phishing OmiseGO.com',
#  'Phishing myehterwallet.co',
#  'Phishing kickico.co',
#  'Phishing qtum-token.com',
#  'Phishing iconexus.social',
#  'Phishing omise-go.io',
#  'Phishing enigma-tokens.co',
#  'Phishing centra.credit',
#  'Phishing kin-klk.com',
#  'Scamming the-ether.pro',
#  'Phishing monetha.me',
#  'Phishing ico-nexus.social',
#  'Phishing kirkik.com',
#  'Phishing red-pulse.tech',
#  'Phishing myethwallet.io',
#  'Fake ICO monetha-crowdsale.com',
#  'Phishing blockstack.network',
#  'Phishing kyber-network.co',
#  'Scamming ethermixer.com',
#  'Phishing kin.kikpro.co',
#  'Phishing change-bank.co',
#  'Phishing change-bank.co',
#  'Phishing monetha.ltd',
#  'Phishing dmarket.ltd',
#  'Phishing tenxpay.io',
#  'Phishing protostokenhub.com',
#  'Phishing kybernet.network',
#  'Phishing reall.markets',
#  'Phishing etnerscan.io',
#  'Phishing kinkik.in',
#  'Phishing smartcontract.live',
#  'Phishing air-token.com',
#  'Phishing smartcontractlink.com',
#  'Phishing bitj0b.io',
#  'Phishing etherparty.in',
#  'Scam pyro0.github.io',
#  'Phishing vlberate.io',
#  'Phishing cindicator.pro',
#  'Phishing change-bank.org',
#  'Phishing etherdelta.gilthub.io',
#  'Phishing raidan.network',
#  'Phishing soam.co',
#  'Phishing etherdelta.githulb.io',
#  'Phishing upfirng.com',
#  'Phishing smartlands.tech',
#  'Phishing omegaone.co',
#  'Phishing enjincoin.pw',
#  'Phishing centra.vip',
#  'Phishing warchain.org',
#  'Phishing dentacoin.in',
#  'Phishing myehterwaliet.com',
#  'Phishing quantstamp.com.ua',
#  'Phishing request-network.net',
#  'Phishing enjincoin.me',
#  'Phishing ripiocreditnetwork.co',
#  'Phishing artoken.co',
#  'Scamming chainlink.tech',
#  'Phishing omisegotoken.com',
#  'Scamming ziber.io',
#  'Scamming ziber.io',
#  'Phishing unlversa.io',
#  'Phishing stormtoken.eu',
#  'Phishing stormtoken.cc',
#  'Phishing raidens.network',
#  'Phishing enjincoin.sale',
#  'Phishing quantstamp.com.co',
#  'Phishing quantslamp.com',
#  'Phishing herotokens.io',
#  'Phishing dmarket.pro',
#  'Phishing stormtoken.co',
#  'Phishing ico.ripiocredits.com',
#  'Phishing privatix.live',
#  'Phishing senstoken.com',
#  'Phishing vvanchain.org',
#  'Phishing storntoken.com',
#  'Phishing storm-token.com',
#  'Phishing storm-token.com',
#  'Phishing ripiocredit.net',
#  'Phishing datum.sale',
#  'Phishing enijncoin.io',
#  'Phishing myetereumwallet.com',
#  'Phishing quantsstamps.com',
#  'Phishing blockstack.one',
#  'Phishing xn--quanstamp-tmd.com',
#  'Phishing elite888-ico.com',
#  'Phishing requestnetwork.live',
#  'Phishing propsproject.tech',
#  'Phishing omisegotoken.com',
#  'Phishing qauntstamp.com',
#  'Phishing xn--hapeshit-ez9c2y.com',
#  'Phishing xn--waxtokn-y8a.com',
#  'Phishing raiden.online',
#  'Phishing stormltoken.com',
#  'Phishing tokensale.gizer.in',
#  'Phishing t-zero.org',
#  'Phishing riaden.network',
#  'Phishing tokensale.kyber.digital',
#  'Phishing tokensale.gamefllp.com',
#  'Phishing statustoken.im',
#  'Phishing xn--quanttamp-42b.com',
#  'Phishing wanchains.org',
#  'Phishing ico-wacoin.com',
#  'Phishing tokenselfkey.org',
#  'Phishing quantstamp-ico.com',
#  'Phishing wallet-ethereum.net',
#  'Phishing xn--zero-zxb.com',
#  'Phishing privatix.top',
#  'Phishing changellyli.com',
#  'Phishing sirin-labs.com',
#  'Phishing sirin-labs.com',
#  'Phishing dmarkt.io',
#  'Phishing bitclaive.com',
#  'Phishing wancha.in',
#  'Phishing sirinlbs.com',
#  'Phishing sirnlabs.com',
#  'Phishing qlink-ico.com',
#  'Phishing atlant.solutions',
#  'Phishing ethconnect.live',
#  'Scamming etherzero.org',
#  'Phishing propsprojects.com',
#  'Phishing cashaa.co',
#  'Phishing spectre-ai.org',
#  'Phishing propsproject.org',
#  'Phishing storrntoken.com',
#  'Scamming linknetwork.co',
#  'Phishing dai-stablecoin.com',
#  'Phishing envlon.org',
#  'Phishing real-markets.io',
#  'Phishing wanchain.network',
#  'Phishing bluzelle.site',
#  'Phishing autcus.org',
#  'Phishing envoin.org',
#  'Phishing oracles-network.org',
#  'Phishing envion.one',
#  'Phishing t-zero.org',
#  'Phishing icoselfkey.org',
#  'Phishing iost.co',
#  'Phishing tronlab.co',
#  'Phishing singularty.net',
#  'Phishing bluzelle-ico.eu',
#  'Scamming ether-wallet.org',
#  'Phishing utrust.so',
#  'Phishing xn--myeherwalet-ns8exy.com',
#  'Phishing privatix.pro',
#  'Phishing selfkey.co',
#  'Phishing singularitynet.info',
#  'Phishing sether.in',
#  'Phishing bluzele.sale',
#  'Phishing ralden.network',
#  'Phishing urtust.io',
#  'Phishing cobinhood.io',
#  'Phishing token-selfkey.org',
#  'Phishing sirin-labs.org',
#  'Phishing bluzelle-ico.com',
#  'Phishing ethereum-zero.com',
#  'Phishing omisegonetwork.site',
#  'Phishing ripiocerdit.network',
#  'Phishing bluzelle.pro',
#  'Phishing bluzelie.com',
#  'Phishing charge-bank.com',
#  'Phishing ton-gramico.com',
#  'Phishing bleuzelle.com',
#  'Phishing paywithlnk.com',
#  'Fake ICO district0x.net',
#  'Phishing mobus.network',
#  'Phishing nyeihitervvallat.com',
#  'Phishing xn--nvion-hza.org',
#  'Phishing bluzelle.eu',
#  'Phishing bluzelle.eu',
#  'Phishing ico-bluzelle.com',
#  'Phishing gramico.info',
#  'Phishing envion-ico.org',
#  'Phishing tongramico.com',
#  'Phishing beetoken-ico.com',
#  'Scamming tron-wallet.info',
#  'Phishing nucleus-vision.eu',
#  'Phishing envione.org',
#  'Phishing nucleus-vision.org',
#  'Phishing refereum-ico.eu',
#  'Phishing sirinlabs.co',
#  'Phishing nucleuss.vision',
#  'Phishing data-token.com',
#  'Phishing daditoken.com',
#  'Phishing dock.promo',
#  'Phishing ripiocredlt.network',
#  'Phishing docks.site',
#  'Scamming ethereum-giveaway.org',
#  'Phishing daddi.cloud',
#  'Phishing republic-protocol.net',
#  'Phishing data-wallet.co',
#  'Phishing simpletoken.live',
#  'Phishing dadi-cloud.net',
#  'Phishing tokensale-fusion.org',
#  'Phishing sparc.pro',
#  'Phishing wanchainetwork.org',
#  'Phishing oracls.network',
#  'Phishing stormtokens.io',
#  'Phishing refereum-token.com',
#  'Phishing block-v.io',
#  'Phishing adhive.net',
#  'Phishing bluzelle.promo',
#  'Phishing gatcoins.io',
#  'Phishing gatcoins.io',
#  'Phishing beetoken-ico.eu',
#  'Phishing globitexico.online/',
#  'Phishing finetrux.com',
#  'Phishing wanchainfunding.org',
#  'Phishing tokensale-dock.io',
#  'Phishing republicprotocol.eu',
#  'Phishing gladius.ws',
#  'Scamming ethzero-wallet.org',
#  'Phishing sether.ws',
#  'Phishing havven.xyz',
#  'Phishing wanchainalliance.org',
#  'Phishing polyswarm.tech',
#  'Phishing medicalchian.com',
#  'Phishing wanchainltd.org',
#  'Scamming 6khb.payment-checker-ethereum-id-bslyftexjuwcgv8.filesusr.com',
#  'Phishing wanchainfoundation.org',
#  'Phishing sale-dock.com',
#  'Phishing remme-ico.eu',
#  'Scamming neonexchanges.org',
#  'Phishing fintrux.eu',
#  'Phishing polyswarm.bid',
#  'Phishing elherdelta.io',
#  'Phishing token-gram.org',
#  'Phishing zeepln.io',
#  'Phishing dock-tokensale.eu',
#  'Phishing fundrequest.info',
#  'Phishing arcblock.eu',
#  'Phishing sale-earn.com',
#  'Phishing polyswarm.pw',
#  'Scamming akasha-world.com',
#  'Phishing xn--fuson-1sa.org',
#  'Phishing iost.co',
#  'Phishing el-petro-coin.com',
#  'Phishing dfinlty.org',
#  'Phishing docai.science',
#  'Phishing dock.io-bonus.online',
#  'Phishing havvens.win',
#  'Phishing originprotocol.io',
#  'Phishing wanchain.cloud',
#  'Phishing seele.promo',
#  'Phishing tokensale.xn--havve-7l1b.com',
#  'Phishing seele-token.pro',
#  'Phishing dock.so',
#  'Phishing ico-havven.org',
#  'Scamming reeveclancy.wixsite.com',
#  'Phishing dflinity.org',
#  'Scamming eth.secure-transactionssecure.com',
#  'Phishing dock.so',
#  'Phishing ataritoken.ltd',
#  'Phishing token.gonetwork.pro',
#  'Phishing gatscoin.io',
#  'Scamming ethergate.space',
#  'Phishing play.google.com/store/apps/details?id=com.ether.etherdelta',
#  'Scamming ethfreepays.com',
#  'Phishing polyswarm.in',
#  'Phishing havven.promo',
#  'Phishing havven-ico.eu',
#  'Phishing telegram.ceo',
#  'Phishing electrify-asia.info',
#  'Phishing xn--thabyss-u8a.com',
#  'Phishing havven.sale',
#  'Scamming bittrex-give.com',
#  'Phishing tomocoln.io',
#  'Phishing dflnlty.org',
#  'Scamming binance-give.com',
#  'Scamming giveaway-ethereum.org',
#  'Scamming paveldurov.bitballoon.com',
#  'Phishing havvenio.com',
#  'Scamming musk.gift',
#  'Scamming eth953883.htmlcomponentservice.com',
#  'Scamming xn--binnce-y0a.com',
#  'Scamming myetherwallet.com.send-transaction_8hlg6z8mgt6zyg.ilil.pw',
#  'Scamming b197c5a2-4c4a-408f-8197-93c81bd6e165.htmlcomponentservice.com',
#  'Scamming eth-cz-319.htmlcomponentservice.com',
#  'Phishing pundix.eu',
#  'Phishing coin-zc.com',
#  'Phishing hawen.io',
#  'Phishing gramtoken.network',
#  'Scamming binance-promo.net',
#  'Scamming trust-cryptopayment.com',
#  'Scamming bitfinex.eu',
#  'Scamming otoeveryday.info',
#  'Scamming ethfreegive.com',
#  'Phishing havven.info',
#  'Scamming ethfreepay.com',
#  'Scamming etherscanio.github.io',
#  'Phishing heavven.io',
#  'Scamming ethopen.com',
#  'Phishing ipsx.promo',
#  'Scamming ethereumtrans.com',
#  'Phishing galaxy-es0lutions.com',
#  'Phishing dock-io.org',
#  'Scamming info-transaction.com',
#  'Scamming ethereum-transfer.online',
#  'Scamming get-ethers.com',
#  'Scamming eth-giveaway.com',
#  'Phishing ico-telegram.club',
#  'Scamming etherfreegive.com',
#  'Phishing hederashashgraph.com',
#  'Scamming ethereum-giveaway.info',
#  'Phishing havven-sale.com',
#  'Scamming campaigntoken.blogspot.de',
#  'Phishing ico-gram.net',
#  'Phishing dftnity.org',
#  'Phishing havven.eu',
#  'Scamming eth-promo.com',
#  'Phishing telegram.trade',
#  'Phishing bluzelle.network',
#  'Phishing telegramsale.com',
#  'Phishing ico-telegram.org',
#  'Phishing ico-telegram.org',
#  'Phishing ico-telegram.org',
#  'Scamming eth-giveaway-209.statichtmlapp.com',
#  'Phishing auctus.org.in',
#  'Scamming ethgiveaway.club',
#  'Phishing tongram.me',
#  'Scamming ethfreeget.com',
#  'Phishing ico-telegram.io',
#  'Scamming claimeth.epizy.com',
#  'Phishing telegram-coin.org',
#  'Phishing mailingserver2.com',
#  'Scamming big-promo-march.tumblr.com',
#  'Phishing cryptongram.org',
#  'Phishing auctus-ico.network',
#  'Scamming eths.bz',
#  'Scamming eth-today.com',
#  'Scamming geth.cc',
#  'Scamming ethr.cc',
#  'Phishing tronlab.co',
#  'Scamming jsfiddle.net/coinbaseethereum/jpL9n72s/show/',
#  'Phishing docs.google.com/forms/d/e/1FAIpQLSeRw1qALR7-rbvOKRM-Wgs1TxmAN5BC7_XzATFiHIVRuRlegQ/viewform',
#  'Scamming cryptoplus.be',
#  'Scamming tronfoundation.us',
#  'Phishing xn--aucts-1gb.org',
#  'Scamming ethpayd.com',
#  'Scamming ethpayd.com',
#  'Scamming safely-transfer.com',
#  'Phishing myethwallet.net',
#  'Scamming ethpay.site',
#  'Scamming ethgiveaway.online',
#  'Phishing decentral.market',
#  'Phishing centratoken.site',
#  'Scamming ethdrop.info',
#  'Phishing tokensale-havven.in',
#  'Scamming eth-private.com',
#  'Scamming geocities.ws/transaction/',
#  'Scamming ethereumgiveaway.win',
#  'Phishing ethc.cc',
#  'Scamming giveawayether.com',
#  'Scamming cz-binance.com',
#  'Scamming ethpromo.com',
#  'Scamming eth.vu',
#  'Phishing metronome-token.io',
#  'Scamming eth.vg',
#  'Scamming payforfees.online',
#  'Scamming azone-web.com',
#  'Scamming ether-giveaway.com',
#  'Phishing auctuss.org',
#  'Scamming etherscan.tech',
#  'Phishing tokenpublicsale.com',
#  'Phishing tomo-coin.io',
#  'Scamming ethpaysafe.com',
#  'Phishing tokensale-adhive.com',
#  'Scamming binance-giveaway.firebaseapp.com',
#  'Phishing celsius-ico.network',
#  'Scamming ethhit.com',
#  'Scamming eth-gives.com',
#  'Scamming ethc.fund',
#  'Phishing dfnity.org',
#  'Scamming etheriumairdrop.com',
#  'Phishing gonetwork.eu',
#  'Scamming eth-giveaway.info',
#  'Scamming givefreeeth.com',
#  'Scamming ethgive.info',
#  'Scamming eth-freesharing.com',
#  'Phishing get-eth.top',
#  'Scamming gether.cash',
#  'Phishing tokentelegram.info',
#  'Phishing gramnetwork.net',
#  'Scamming free-5000eth.com',
#  'Scamming eth-giveaway.trade',
#  'Scamming win-eth.org',
#  'Scamming win-eth.org',
#  'Scamming eth-giving.com',
#  'Scamming ethhit.org',
#  'Scamming neonexchange.online',
#  'Scamming get-ethers.com.cp-32.webhostbox.net',
#  'Scamming myetherpromo.com',
#  'Scamming securepayeth.com',
#  'Scamming ethereumdrop.com',
#  'Scamming eth-transaction.secure.kissr.com',
#  'Scamming 5000eth-giveaway.online',
#  'Scamming eth-transactions.com',
#  'Scamming collect-eth.com',
#  'Scamming ethsend.online',
#  'Scamming binance.ethdeal.info',
#  'Scamming bonus.ether-gifts.com',
#  'Scamming givingawayeth.com',
#  'Scamming ethereumpromo.info',
#  'Scamming give-5000eth.com',
#  'Scamming btc-gifts.info',
#  'Phishing ico-ton.org',
#  'Phishing tonogram.org',
#  'Scamming free5000eth.com',
#  'Scamming givingawayethereum.com',
#  'Scamming get-ether.me',
#  'Scamming eth-transaction.site44.com',
#  'Phishing gate1.eths.vu',
#  'Scamming give5000eth.com',
#  'Scamming claim.ethdeal.info',
#  'Scamming ethn.vu',
#  'Phishing jsfiddle.net/Croxy/Luwtc9yu/33/show/',
#  'Scamming get5000eth.com',
#  'Scamming get5000eth.com',
#  'Scamming etherum.site123.me',
#  'Scamming gift-5000eth.com',
#  'Phishing polyswamr.io',
#  'Phishing fusion-ico.com',
#  'Scamming getyoureth.com',
#  'Scamming ethereumdrop.org',
#  'Scamming offpromoeth.com',
#  'Scamming bonus.ether-gift.com',
#  'Scamming ethforeth.com',
#  'Scamming ethtoget.com',
#  'Scamming ethereumgiveaway5000.com',
#  'Scamming eth-giveaway-vote.bitballoon.com',
#  'Scamming 5000eth-gift.com',
#  'Scamming ethgiveaway.live',
#  'Phishing ico-telegramcoin.com',
#  'Scamming eth-givingaway.com',
#  'Scamming ethereumpomo.online',
#  'Phishing nkn-token.io',
#  'Scamming geteths.live',
#  'Scamming 5000eth.rf.gd',
#  'Scamming gift5000eth.com',
#  'Scamming etherscan-giveaway.epizy.com',
#  'Scamming ethtransaction.unaux.com',
#  'Scamming ethtransaction.ezyro.com',
#  'Scamming ethtransaction.ezyro.com',
#  'Scamming take5000eth.com',
#  'Scamming bonus.eth-gifts.com',
#  'Scamming bonus.ether-gives.com',
#  'Scamming promaestros.co.uk',
#  'Phishing pyapay.co',
#  'Scamming bonus.ethersgifts.com',
#  'Scamming get-ethereum.cc',
#  'Phishing hederahashgraph.store',
#  'Scamming free-give-eth.com',
#  'Phishing tokentelegram.live',
#  'Scamming ethpromo.net',
#  'Scamming ethershare.us',
#  'Scamming 5000eth-giveaway.com',
#  'Phishing daostack-token.io',
#  'Phishing daostack-token.io',
#  'Phishing ico-telegram.co',
#  'Scamming eth-today.rf.gd',
#  'Scamming giveaway-eth.com',
#  'Scamming giveaway-eth.com',
#  'Phishing icotoken-current.top',
#  'Phishing hederahashgraph.tokencrowdsale.info',
#  'Scamming transfer-address-confirmation.droppages.com',
#  'Scamming ethereums.live',
#  'Scamming ether-promo.getforge.io',
#  'Phishing ocoins.tech',
#  'Scamming 5000ethgift.com',
#  'Scamming ether_promo.kissr.com',
#  'Scamming eth-get.online',
#  'Phishing shivom.sale',
#  'Scamming eth-give.kissr.com',
#  'Scamming secure-transaction-confirmation.droppages.com',
#  'Phishing tomocoin.network',
#  'Scamming freecoingifts.com',
#  'Scamming gameofdeception.get-5000-eth.com',
#  'Phishing quarkchain.tech',
#  'Phishing quarkchain.tech',
#  'Scamming ethereum.vu',
#  'Scamming bonus.gift-ethers.com',
#  'Scamming get-eth.us',
#  'Scamming get-eth.us',
#  'Scamming eth-giveavvay.online',
#  'Phishing telegram-token.io',
#  'Scamming take-eth.online',
#  'Scamming daily-free-eth.net',
#  'Phishing Telegram',
#  'Phishing remme.live',
#  'Scamming bonus.ethersgift.com',
#  'Scamming ethereum.vu',
#  'Scamming eosrewards.io',
#  'Phishing hederahashgraph.online',
#  'Scamming daostack-ico.io',
#  'Phishing dfinity.org.in',
#  'Phishing dav-network.io',
#  'Phishing dav-network.io',
#  'Phishing dav-network.io',
#  'Phishing quarkchain.website',
#  'Phishing quarkchain.de',
#  'Phishing quarkchain.de',
#  'Phishing riden.network',
#  'Scamming promo.ethereumbonus.online',
#  'Scamming musk.vu',
#  'Scamming etherblessings.com',
#  'Scamming etherfree.tech',
#  'Scamming etherfree.tech',
#  'Scamming eth-gift.tw1.su',
#  'Scamming ethgiveaway.org',
#  'Scamming bonus.etherpayout.com',
#  'Scamming 5000eth.net',
#  'Scamming bonus.ethergives.com',
#  'Scamming secureceth.com',
#  'Scamming 5000eth-giveaway.getforge.io',
#  'Scamming bonus.gift-ether.com',
#  'Scamming ether.vu',
#  'Phishing dimnsions.network',
#  'Scamming ethplatform.org',
#  'Scamming ethplatform.org',
#  'Scamming 5000eth.org',
#  'Scamming twitter.com/Aurora__dao/status/960683836463075328',
#  'Phishing metronometoken.io',
#  'Scamming address-transfer-confirmation.droppages.com',
#  'Scamming waves-ethereum-eth.org',
#  'Scamming eth-promotion.getforge.io',
#  'Phishing quarkchain-token.io',
#  'Phishing quarkchain-tokensale.io',
#  'Scamming authorize.live',
#  'Phishing swaapy.network',
#  'Scamming twitter.com/cz_binance',
#  'Scamming free-eth.news',
#  'Scamming bonus.ethereum-giveaway.net',
#  'Scamming get-ethereum.info',
#  'Scamming 5000ethereum.online',
#  'Scamming etherget.online',
#  'Scamming nathanielpopper.promo-eths.com',
#  'Scamming bonus.giftethers.com',
#  'Scamming give-ethereum.org',
#  'Phishing originprotocol.tokenpublicsales.com',
#  'Scamming secure093555613.safethpay.com',
#  'Phishing hederahashgaph.com',
#  'Scamming get.ico-eth.org',
#  'Scamming ethgive.online',
#  'Phishing quarkchain-ico.io',
#  'Phishing quarkchain-ico.io',
#  'Scamming eth-promo.net',
#  'Scamming ethconfirm.info',
#  'Scamming it-now-eth.com',
#  'Phishing quarkchain.pl',
#  'Scamming secure375446884521.safeethpay.com',
#  'Scamming giveavvay-10000eth.online',
#  'Scamming smartexchangecenter.tk',
#  'Scamming ethdropnew.ml',
#  'Phishing dav.icocrowdsale.io',
#  'Scamming ethg.cz',
#  'Phishing intchain.network',
#  'Scamming get.ico-eth.net',
#  'Scamming twitter.com/VltalkButerin',
#  'Scamming promoeth.net',
#  'Scamming claim-eth.com',
#  'Phishing brickblocks.io',
#  'Phishing myetherwallet.in',
#  'Phishing shivoms.io',
#  'Phishing quarkchain-presale.io',
#  'Phishing quarkchain.in',
#  'Scamming send.ethergot.com',
#  'Phishing havven.top',
#  'Scamming secure-ethereum.tw1.su',
#  'Scamming eth-airdrop.com',
#  'Scamming giveawayethereum.win',
#  'Scamming coinbase.droppages.com',
#  'Phishing eden-chain.io',
#  'Scamming elon-giveaway.com',
#  'Scamming elon-giveaway.com',
#  'Scamming musk-crypto.info',
#  'Scamming etherget.us',
#  'Scamming ethsgive.com',
#  'Scamming check-ethpayments1.kissr.com',
#  'Scamming ethereum-giveaway.kissr.com',
#  'Scamming ethf.bid',
#  'Scamming get-ether.fund',
#  'Scamming check-ethpayments.kissr.com',
#  'Scamming check-ethpayments.kissr.com',
#  'Scamming ethereum-giveaway.site',
#  'Scamming ethpromoverge.com',
#  'Scamming ethergive.000webhostapp.com',
#  'Scamming eth-transact.secure.droppages.com',
#  'Scamming eth.altervista.org',
#  'Scamming eth-airdrop.live',
#  'Scamming paygiveaway.com',
#  'Scamming ethgive.net',
#  'Scamming now-5000ether.paperplane.io',
#  'Scamming geteth.online',
#  'Scamming etherofficial.com',
#  'Scamming ethwitheth.com',
#  'Phishing quarkchain-tokens.io',
#  'Phishing starkware.online',
#  'Scamming ether-promo.org',
#  'Scamming ethbonus.net',
#  'Scamming eth-bonus-live-binance.com',
#  'Scamming eth4free.ml',
#  'Scamming etherfaucet.tech',
#  'Phishing gramnetwork.org',
#  'Scamming ethereum.org-giveaway.live',
#  'Scamming cardanoethereum.com',
#  'Scamming ethergifting.com',
#  'Scamming ethgiver.com',
#  'Scamming eths.space',
#  'Scamming ethereum-giveaway.tekcities.com',
#  'Phishing ico-telegram.is',
#  'Scamming givefree-eth.com',
#  'Scamming collectmyethers.org',
#  'Scamming securepeth.club',
#  'Scamming ethereum-pay.com',
#  'Phishing myetherwaillet.com',
#  'Scamming ethgive.me',
#  'Phishing tronfoundation.cc',
#  'Scamming coin-secure-transaction.com',
#  'Phishing eth.promo-etherum.com',
#  'Scamming eth.kissr.com',
#  'Scamming ethgiveaway.zkr.kr',
#  'Scamming ethgrab.com',
#  'Phishing quarkchain.live',
#  'Scamming tron-mainnet.network',
#  'Scamming ethsecure.info',
#  'Phishing bestethgift.com',
#  'Scamming ethbigpromo-com.1gb.ru',
#  'Scamming bitcoinbravado.io',
#  'Scamming ethpromo.gift',
#  'Scamming ethgw.info',
#  'Scamming ethereum-get.info',
#  'Phishing docs.google.com',
#  'Scamming etherkickstart.com',
#  'Scamming free-eth.paperplane.io',
#  'Phishing eth-get.com',
#  'Scamming eth-share.com',
#  'Scamming free-eths.paperplane.io',
#  'Phishing dfinity.ml',
#  'Scamming eth-giveaway.updog.co',
#  'Scamming eth-give.me',
#  'Phishing secure.ethtogive.com',
#  'Scamming tron-coin.org',
#  'Scamming get-5000eth.com',
#  'Scamming coinbase-eth-giveaway.com',
#  'Scamming getmyetho.paperplane.io',
#  'Phishing giveaway-ether.info',
#  'Phishing giveaway-ether.info',
#  'Scamming ethcollection.paperplane.io',
#  'Scamming bitwelfare.biz',
#  'Scamming etherums-givingaway.atspace.tv',
#  'Scamming ethconfirm.com',
#  'Scamming eth-gift.com.paperplane.io',
#  'Scamming 5000-eth.paperplane.io',
#  'Scamming ethereumdrop.batcave.net',
#  'Phishing tron-block.info',
#  'Scamming collecteth.com',
#  'Scamming gift-10000eth.com',
#  'Phishing etherscan.ltd',
#  'Phishing ethxchanges.com',
#  'Phishing giveawaycrypto.org',
#  'Scamming changellyico.bitballoon.com',
#  'Phishing idice.epizy.com',
#  'Phishing ether-give.club',
#  'Phishing ico-telegram-ton.com.ru',
#  'Scamming quick.payeths.com',
#  'Scamming 20000.paperplane.io',
#  'Scamming ether-giveaway.atspace.eu',
#  'Scamming eth-drop.com',
#  'Scamming etherspromo.org',
#  'Scamming verifiedeth.com',
#  'Scamming gether-gift.com',
#  'Scamming ethpays.me',
#  'Scamming ethdeals.org',
#  'Scamming airdrop24.com',
#  'Phishing safepay-eth.org',
#  'Scamming cryptoaway.org',
#  'Scamming cryptocandies.updog.co',
#  'Phishing get.ethpublic.com',
#  'Scamming eth-free.github.io',
#  'Phishing ethpublic.com',
#  'Scamming klareol5.ru',
#  'Scamming ethnow.me',
#  'Phishing blttrex.us',
#  'Phishing auctus.network',
#  'Scamming eth-request.org',
#  'Scamming eth-giving.ga',
#  'Scamming output.jsbin.com/ciqukak',
#  'Scamming receive-ether.com',
#  'Scamming give-eth.online',
#  'Phishing eth-givebacknow.tumblr.com',
#  'Scamming eth-securepay.com',
#  'Phishing Fake DaoStack ICO Telegram',
#  'Scamming ethergift.org',
#  'Scamming dropeth.org',
#  'Scamming ethers.cz',
#  'Phishing sparkster.pro',
#  'Phishing arweave.pw',
#  'Scamming dfinitydrop.ml',
#  'Scamming getnoweth.com',
#  'Scamming eth-giveaway.co.nf',
#  'Phishing myeosdac.top',
#  'Scamming get-eths.com',
#  'Scamming collect.ethforyou.com',
#  'Scamming ethaddress.neocities.org',
#  'Scamming eth-promo.kissr.com',
#  'Scamming promo-ether.com',
#  'Scamming give-5000eth.org',
#  'Scamming gift-5000eth.org',
#  'Scamming eth-payment.online',
#  'Scamming transfer.saferpayeth.com',
#  'Phishing getethnow.com',
#  'Phishing ethpromo.cc',
#  'Scamming pay.ethconfirm.com',
#  'Scamming ethsecurepay.com',
#  'Scamming eth-24h.com',
#  'Scamming mycrypton.net',
#  'Scamming ethereum-drops.com',
#  'Scamming binancegiveaway.org',
#  'Phishing etheroll.io',
#  'Scamming ethxpromo.com',
#  'Scamming airtake.info',
#  'Scamming ethgiveaways.net',
#  'Scamming ethgiveaways.net',
#  'Scamming coinmakerbot.com',
#  'Scamming coinmakerbot.com',
#  'Scamming coinmakerbot.com',
#  'Phishing sparkster.tech',
#  'Scamming zclassiccoins.com',
#  'Scamming xn--bifinex-fb4c.com',
#  'Scamming etherguide.info',
#  'Phishing Google Doc',
#  'Scamming mycrypto.get-5000-eth.com',
#  'Scamming ethexchans.com',
#  'Scamming give.promoeth.net',
#  'Phishing ethxchanges.com',
#  'Scamming binance-giveaway.com',
#  'Phishing telegra.ph/BlockBrick-Step-By-Step-Guide-on-How-to-Participate-in-the-token-sale-05-09',
#  'Scamming etherpromotion.org',
#  'Scamming ethpubs.com',
#  'Scamming verify.officialeth.com',
#  'Scamming eth-promo.webz.cz',
#  'Scamming ethype.org',
#  'Scamming ethg.me',
#  'Scamming ethbonus.org',
#  'Scamming ethbonus.org',
#  'Scamming get-ether.st',
#  'Scamming 24h.infora.hu',
#  'Phishing gather-gift.com',
#  'Phishing ethpromo.info',
#  'Scamming safe.ethpaynow.com',
#  'Scamming transaction-authorization.droppages.com',
#  'Scamming giveethers.info',
#  'Scamming ethinfo.org',
#  'Scamming ethrewarding.com',
#  'Scamming get-eths-now.com',
#  'Scamming elon-gives.com',
#  'Scamming getethpro.com',
#  'Scamming ethpromo.org',
#  'Scamming ethpromo.org',
#  'Scamming ethpromotions.org',
#  'Phishing edenchain.site',
#  'Scamming eth-givea-way.com',
#  'Phishing sentinelprotocol.pw',
#  'Scamming ethpays.org',
#  'Scamming ethpromo.win',
#  'Phishing brickblockio.info',
#  'Phishing ethereum-get.org',
#  'Scamming giveavvay10000eth.host',
#  'Scamming ethxinfo.com',
#  'Scamming ethcrypto.info',
#  'Scamming ethgift.org',
#  'Scamming ethnow.org',
#  'Scamming today-ethereum.com',
#  'Scamming eth-giveaway.surge.sh',
#  'Scamming ethgives.me',
#  'Scamming giveeth.org',
#  'Phishing ethereum-promo.xf.cz',
#  'Scamming wincheck.org',
#  'Scamming aireth.today',
#  'Scamming eth-box.xf.cz',
#  'Phishing xn--myethrwalt-inbe64c.com',
#  'Fake ICO fantom-foundation.tech',
#  'Scamming give-eth.today',
#  'Phishing sparkster.site',
#  'Phishing ico-telegram.org',
#  'Scamming ethereum-claim.org',
#  'Scamming perfecteth.com',
#  'Scamming safesteth.com',
#  'Scamming ethergive.info',
#  'Scamming personaleth.com',
#  'Scamming elon-shares.com',
#  'Scamming musk-gives.com',
#  'Phishing ethereum.website.tk',
#  'Scamming eth-bonus.org',
#  'Scamming verified.myethergift.com',
#  'Scamming ethshare.org',
#  'Scamming secure.ethscan.us',
#  'Scamming secure.ethscan.us',
#  'Phishing winplatform.io',
#  'Scamming coinsdrop.org',
#  'Scamming event-eth.org',
#  'Scamming event-eth.org',
#  'Scamming ethsafe.net',
#  'Scamming giveaway.ethsafe.net',
#  'Scamming ethgivers.com',
#  'Scamming musk-party-gifts.updog.co',
#  'Scamming ether-promo.unas.cz',
#  'Scamming ethereum-prize.com',
#  'Scamming getethers.org',
#  'Scamming ethgpromo.com',
#  'Scamming eth-air-com.1gb.ru',
#  'Scamming ethers-free.org',
#  'Scamming free-ethers.org',
#  'Scamming free-ethers.org',
#  'Scamming eth-pay.org',
#  'Scamming epromo.cc',
#  'Scamming ethergift.io',
#  'Scamming claimethers.org',
#  'Scamming ethsupport.net',
#  'Scamming safe-claims.info',
#  'Scamming bonus-ethereum.com',
#  'Scamming ethfreegift.org',
#  'Scamming giveawaypromo.org',
#  'Scamming giveawayofficial.info',
#  'Scamming ethereumpromo.org',
#  'Scamming ethereumpromo.org',
#  'Scamming ethereumpromo.org',
#  'Scamming dontmiss.info',
#  'Scamming e10000eth.net',
#  'Scamming grab-eth.com',
#  'Scamming elon-gift.com',
#  'Scamming promo-binance.site',
#  'Scamming valideth.com',
#  'Scamming freeethpromo.com',
#  'Scamming huobitalk.ga',
#  'Scamming get-bitcoins-now.com',
#  'Scamming get-bitcoins-now.com',
#  'Scamming admin.safe-eth.top',
#  'Scamming encoreofficial.com',
#  'Scamming ethpaynet.com',
#  'Scamming ethcelebration.io',
#  'Scamming ethofficialpage.us',
#  'Scamming eth.fanclub.rocks',
#  'Scamming ethereumstash.org',
#  'Scamming etherbonus.live',
#  'Phishing telegram.market',
#  'Scamming freepromoeth.com',
#  'Scamming validbtc.com',
#  'Scamming ethereum-promo.info',
#  'Scamming verify.ethgoldmine.com',
#  'Scamming ethpays.info',
#  'Scamming ethercontest.site',
#  'Scamming ethincrease.com',
#  'Phishing ankr-network.tech',
#  'Scamming swdwd.ethers444.online',
#  'Scamming medium.ethereumfoundation.top',
#  'Scamming teslaforfree.wordpress.com',
#  'Scamming officialgiveaway.org',
#  'Scamming officialgiveaway.info',
#  'Scamming top-ethereum.com',
#  'Scamming top-ethereum.com',
#  'Scamming top-ethereum.com',
#  'Scamming top-ethereum.com',
#  'Scamming medium.com/@Ray23699991/click-here-get-it-now-10-000-eth-6488a2116e0c',
#  'Scamming ethereum-event.com',
#  'Scamming bitcoinvest.cc',
#  'Scamming ethofficial.net',
#  'Scamming securepay-eth.org',
#  'Scamming ethinwallet.com',
#  'Scamming bonus.eth-promo.org',
#  'Scamming ethextra.net',
#  'Phishing w-tron.org',
#  'Scamming eosreward.io',
#  'Scamming wineths.top',
#  'Scamming eth-gift.club',
#  'Scamming eth-give.net',
#  'Scamming ethergiveaway.site',
#  'Scamming ethergiveaway.site',
#  'Scamming claimeth.org',
#  'Scamming post.mediumdotcom.top',
#  'Scamming mediumblog.org',
#  'Scamming cryptoyodas.tumblr.com',
#  'Scamming plus.google.com/u/1/114056019931432957256/posts/Hk16DTRy8bB',
#  'Scamming eth-news.co',
#  'Scamming celebration-eth.com',
#  'Scamming celebration-eth.com',
#  'Scamming celebration-eth.com',
#  'Scamming medium-promotion.com',
#  'Scamming celebration-eth.com',
#  'Scamming medium-promotions.com',
#  'Scamming ethbig.net',
#  'Scamming offer.supporteth.com',
#  'Scamming eth.tronbonus.network',
#  'Scamming tronics.promo',
#  'Scamming giveaway.eth-safe.net',
#  'Scamming giveaway.claimeth.net',
#  'Scamming 10000ethereum.com',
#  'Scamming giveawaycrypto.info',
#  'Scamming secure.ethoffers.net',
#  'Scamming crypto-promo.website',
#  'Scamming ethmore.net',
#  'Scamming ethereumdrop.info',
#  'Scamming dapp.doubledouble.io',
#  'Scamming ethereum-givaway.social',
#  'Scamming ethpromofree.com',
#  'Scamming ethpromofree.com',
#  'Phishing https://docs.google.com/forms/d/e/1FAIpQLSdYUpUlj1mjvg9KkU-CMHYILLjWFIOFRtuqBiqp1fbzoTsxNA/formResponse',
#  'Scamming official-promo.org',
#  'Scamming safe.eth10000.org',
#  'Phishing vechain-platform.org',
#  'Scamming ethonline.io',
#  'Scamming ethonline.io',
#  'Scamming ethonline.io',
#  'Scamming ethonline.io',
#  'Scamming ethonline.io',
#  'Scamming tokenaway.com',
#  'Scamming lotsofeth.com',
#  'Scamming 5000eth-giving.online',
#  'Scamming 5000eth-giving.online',
#  'Scamming ethereumpromote.wixsite.com',
#  'Scamming etherpromotion.org',
#  'Scamming give-ethprize.com',
#  'Scamming ethvert.com',
#  'Scamming officialmcafee.github.io',
#  'Scamming secure.ethsoffer.com',
#  'Scamming getethtoday.com',
#  'Scamming ethereumpromo.win',
#  'Scamming secure.ethgiftnow.com',
#  'Scamming crypto-payout.tk',
#  'Scamming tron-event.network',
#  'Phishing stormtoken.site',
#  'Scamming claim-event-eth.biz',
#  'Scamming ethpromo-giveaway.atspace.cc',
#  'Scamming musk-surprise.com',
#  'Scamming musk-present.blogspot.com',
#  'Scamming elon-giveaway.org',
#  'Scamming official-giveaway.org',
#  'Scamming ethaway.com',
#  'Scamming yobit.tilda.ws',
#  'Scamming air-drop.org',
#  'Phishing sparkster.com.de',
#  'Scamming eth.mediumblog.org',
#  'Scamming evotrustllc.com',
#  'Scamming givefreecoin.com',
#  'Scamming giveusethereum.com',
#  'Scamming giveusether.com',
#  'Scamming getyoureths.com',
#  'Scamming verify.bonuseth.info',
#  'Scamming ethbounty.info',
#  'Phishing ethgive.global',
#  'Scamming eth5000.io',
#  'Scamming ethmore.live',
#  'Scamming eth4everyone.com',
#  'Scamming ethcountdown.ga',
#  'Phishing bitcryptonex.com',
#  'Scamming ethtwitter.com',
#  'Scamming ethdrop.co',
#  'Scamming instantethpromotion.cx',
#  'Scamming eth2018.net',
#  'Scamming ethergiftnow.com',
#  'Scamming mediumblogsot.top',
#  'Scamming eosbounty.co',
#  'Scamming musk-official-giveaway.com',
#  'Scamming ethvert.com',
#  'Scamming amazy-eth.com',
#  'Scamming eth-give.info',
#  'Phishing saferpayether.com',
#  'Scamming event-eth-giveaway.com',
#  'Scamming airdrop-event.info',
#  'Phishing stormxtoken.com',
#  'Scamming ethgiveawaygift.info',
#  'Phishing ethfreebie.icu',
#  'Phishing ethereumbonus.org',
#  'Scamming bigethgift.com',
#  'Scamming ethsafe.info',
#  'Scamming getethernow.org',
#  'Scamming officialairdrop.com',
#  'Scamming coincapitals.org',
#  'Scamming promo.etherpay.site',
#  'Scamming getbigeth.com',
#  'Scamming bounty-eth.com',
#  'Scamming ethescan.info',
#  'Scamming givecoins.info',
#  'Scamming ethgiveaway.io',
#  ...]

# %%
df['addresses'] = addresses

# %%
df['precision'] = prec

# %%
df.head()
# Out:
#                                            addresses  \
# 0         0x2b065809f6ec6df32878bcd26711a0e2bcf59c26
# 1  0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f3...
# 2  0x2dfe2e0522cc1f050edcc7a05213bb55bbb36884ec94...
# 3  0x1c6e3348a7ea72ffe6a384e51bd1f36ac1bcb4264f46...
# 4         0xd0cc2b24980cbcca47ef755da88b220a82291407
#
#                        precision
# 0  Phishing myetherwallet.com.de
# 1      Phishing myetherwallet.us
# 2      Phishing myetherwallet.us
# 3      Phishing myetherwallet.us
# 4     Phishing myelherwallel.com

# %%
# Il figure des transactions dans ce tableau, on va les traiter séparément
ind_trans = np.argwhere([len(i) > 42 for i in df.addresses])[:,0]

# %%
# Liste des transactions qui figurent dans la liste des addresses a corriger

df.addresses[[len(i) > 42 and i[0:2] == '0x' for i in df.addresses]]
for j in df.addresses[[len(i) > 42 and i[0:2] == '0x' for i in df.addresses]]:
    print(j)
# Out:
# 0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f3c867664e43a626d878c0
# 0x2dfe2e0522cc1f050edcc7a05213bb55bbb36884ec9468fc39eccc013c65b5e4
# 0x1c6e3348a7ea72ffe6a384e51bd1f36ac1bcb4264f461889a318a3bb2251bf19

# %%
urls = []
for j in df.addresses[[len(i) > 42 and i[0:2] == '0x' for i in df.addresses]]:
    urls.append("https://www.etherchain.org/tx/{}".format(j))
# Out:
# ['https://www.etherchain.org/tx/0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f3c867664e43a626d878c0', 'https://www.etherchain.org/tx/0x2dfe2e0522cc1f050edcc7a05213bb55bbb36884ec9468fc39eccc013c65b5e4', 'https://www.etherchain.org/tx/0x1c6e3348a7ea72ffe6a384e51bd1f36ac1bcb4264f461889a318a3bb2251bf19']

# %%
source = requests.get("https://www.etherchain.org/tx/1c6e3348a7ea72ffe6a384e51bd1f36ac1bcb4264f461889a318a3bb2251bf19").text

# %%
soup = BeautifulSoup(source,'lxml')
extract_data = soup.find('div',class_="table-responsive") # on récupère l'ensemble du tableau

# %%
extract2 = extract_data.find('table',class_="table table-sm borderless")

# %%
extract2.find_all('td')[4].find('a')
string = str(extract2.find_all('td')[4].find('a'))

# %%
remove_html_markup(string)
# Out:
# '0xc57f1148855e67763a694F7f2C0e68230AdC686E'

# %%
string = str(extract2.find_all('tr')[5].find('td'))

# %%
string2 = remove_html_markup(string)

# %%
s = str()
for i in range(len(string2)):
    if string2[i] != 'E':
        s+= string2[i]
    else:
        break

# %%
s
# Out:
# '4.33864 '

# %%
float(s)
# Out:
# 4.33864

# %%
source = requests.get("https://www.etherchain.org/account/c57f1148855e67763a694f7f2c0e68230adc686e").text
soup = BeautifulSoup(source,'lxml')
extract_data = soup.find('p',class_="mb-4")

# %%
balance = remove_html_markup(str(extract_data))
# Out:
# '0 ETH'

# %%
extract = soup.find('ul',class_="list-unstyled list-spaced")

# %%
string = str(extract.find_all('li')[2])

# %%
remove_html_markup(string)
# Out:
# 'Sent 47 &amp; Received 21 Txns'

# %%
[int(s) for s in remove_html_markup(string).split() if s.isdigit()]
# Out:
# [47, 21]

# %%
np.sum([int(s) for s in remove_html_markup(string).split() if s.isdigit()])
# Out:
# 68

# %%
np.argwhere([len(i) > 42 and i[0:2] == '0x' for i in df.addresses])[:,0]
# Out:
# array([1, 2, 3])

# %%
scam_data.columns
# Out:
# Index(['0x2b065809f6ec6df32878bcd26711a0e2bcf59c26',
#        '0x11c058c3efbf53939fb6872b09a2b5cf2410a1e2c3f3c867664e43a626d878c0',
#        '0x2dfe2e0522cc1f050edcc7a05213bb55bbb36884ec9468fc39eccc013c65b5e4',
#        '0x1c6e3348a7ea72ffe6a384e51bd1f36ac1bcb4264f461889a318a3bb2251bf19',
#        '0xd0cc2b24980cbcca47ef755da88b220a82291407',
#        '0xaa1886de3f70a3ef502ea1379a311c5b4e05f3fd',
#        '0x240e125c20a4cc84bd6e7f8d1fd07aff4c06d43d',
#        '0x1d60606d8a09b5015d773a80b0c660bb8d91809c',
#        '0xadf5b0c2103598fb66a61714152f1d1717d49fe0',
#        '0xba83e9ce38b10522e3d6061a12779b7526839eda',
#        ...
#        '0x8bba1a1c5e9f72c2ce97a240a7878dd4ae803b61',
#        '1gj9tymgjcfsnjprkdcaugemewix2ysbdl',
#        '0x0bb4251b8c5e8acb27d6809d77a10aa1cacc5144',
#        'qzh7l8neh3v868uzu74qpyat4gjz2rdv0yhjktqcp2',
#        '1lptqoigtdmbrlb76g5w7ceja4wshpag9z',
#        '0x84a8e201cfce8a10b1e721e1940a78a3326b7c97',
#        'qpdjfyy89utdz5ky34exk3s98c9h4ahtwyjgdr9dze',
#        '1mx2sjhokgbrnrukj8nsqzur5vlorulhf7',
#        '0x8f0e5ef93838ffb9bc2c5afb34c32f55ea97a932',
#        'qzuqzn8y2726k2pwx3767zmja9m9wdh5wyukklr6kf'],
#       dtype='object', length=2133)

# %%
def parse_all_ethscam():
    
    # On importe d'abord l'ensemble des données non formatées du site 
    scam_data = get_ethscam_data()
    
    # Indices des adresses scams uniquement liées a l'ETH
    ind = scam_data.iloc[2] == "ETH" 
    ind = np.argwhere(ind)[:,0]
    
    # Création du tableau "propre"
    
    df = pd.DataFrame()
    
    # Récupération des addresses 
    addresses = np.array(scam_data.iloc[:,ind].columns)
    
    # Récupération des descriptifs 
    prec1 = np.array(scam_data.iloc[1,ind])
    prec2 = np.array(scam_data.iloc[6,ind])
    prec = []
    for i,j in zip(prec1,prec2):
        prec.append(i+" "+j)
    
    # On remplit le tableau 
    df['addresses'] = addresses
    df['precision'] = prec
    
    # On retire les addresses non ETH
    
    ind_retirer = np.argwhere([i[0:2] != '0x' for i in df.addresses])[:,0]
    df = df.drop(ind_retirer)
    
    balances = np.zeros(df.shape[0])
    txns = np.zeros(df.shape[0])
    
    """
    
    ADRESSES A CORRIGER D ABORD
    
    """
    
    # Le tableau contient parfois des transactions au lieu d'addresses, on doit corriger
    urls = []
    
    for j in df.addresses[[len(i) > 42 and i[0:2] == '0x' for i in df.addresses]]:
        urls.append("https://www.etherchain.org/tx/{}".format(j))  
    
    balances_corr = []
    txns_corr = []
    
    ind_corr = np.argwhere([len(i) > 42 and i[0:2] == '0x' for i in df.addresses])[:,0]
    j = 0
    
    for url in urls:
        source = requests.get(url).text
        soup = BeautifulSoup(source,'lxml')
        extract_data = soup.find('div',class_="table-responsive") # on récupère l'ensemble du tableau     
        extract2 = extract_data.find('table',class_="table table-sm borderless")
        
        # On souhaite récupérer l'addresse "To" 
        string = str(extract2.find_all('td')[4].find('a'))
        address = remove_html_markup(string)
        
        # Une fois que l'on possède l'addresse liée à la transaction frauduleuse, on tire ses informations
        source = requests.get("https://www.etherchain.org/account/{}".format(address)).text
        soup = BeautifulSoup(source,'lxml')
        extract_data = soup.find('p',class_="mb-4") 
        string = remove_html_markup(str(extract_data))
    
        s = str()
        for i in range(len(string)):
            if string[i] != 'E':
                s+= string[i]
            else:
                break
        
        balance = float(s)
        balances_corr.append(balance)
        
        # On récupère aussi les nombres de transactions 
        
        extract = soup.find('ul',class_="list-unstyled list-spaced") 
        string = str(extract.find_all('li')[2])
        string = remove_html_markup(string)
        txn = np.sum([int(s) for s in string.split() if s.isdigit()])
        txns_corr.append(txn)
        
        ind = ind_corr[j]
        balances[ind] = balance
        txns[ind] = txn
        j += 1 
    
    """
    
    ADRESSES NE NECESSITANT PAS DE CORRECTION
    
    """
    
    ind_no_corr = np.argwhere([len(i) == 42 and i[0:2] == '0x' for i in np.array(scam_data.columns)])[:,0]
    n_iter = 0
    ind_errors = []
    
    for j in ind_no_corr:
        n_iter += 1 
        if (n_iter%5 != 0):
            try:
                
                url = df.iloc[ind_no_corr[j],].addresses
                source = requests.get("https://www.etherchain.org/account/{}".format(url)).text
                soup = BeautifulSoup(source,'lxml')
                extract_data = soup.find('p',class_="mb-4") 
                string = remove_html_markup(str(extract_data))

                s = str()
                for i in range(len(string)):
                    if string[i] != 'E':
                        s+= string[i]
                    else:
                        break
                print(j)
                balance = float(s)
       
                balances[j] = balance
        
        # On récupère aussi les nombres de transactions 
        
                extract = soup.find('ul',class_="list-unstyled list-spaced") 
                string = str(extract.find_all('li')[2])
                string = remove_html_markup(string)
                txn = np.sum([int(s) for s in string.split() if s.isdigit()])
        
                txns[j] = txn
            
            except: 
                print("Error")
                ind_errors.append(j)
        else:
            sleep(7)
            
    df['balance'] = balances
    df['txn'] = txns
    
    return(df,ind_errors)

# %%
data_scam,errors = parse_all_ethscam()
# Out:
# 0
# 4
# 5
# 6
# 8
# 9
# 10
# 11
# 13
# 14
# 15
# 16
# 18
# 19
# 20
# 21
# 23
# 24
# 25
# 26
# 28
# 29
# 30
# 31
# 33
# 34
# 35
# 36
# 38
# 39
# 40
# 41
# 43
# 44
# 45
# 46
# 48
# 49
# 50
# 51
# 53
# 54
# 55
# 56
# 58
# 59
# 60
# 61
# 63
# 64
# 65
# 66
# 68
# 69
# 70
# 71
# 73
# 74
# 75
# 76
# 78
# 79
# 80
# 81
# 83
# 84
# 85
# 86
# 88
# 89
# 90
# 91
# 93
# 94
# 95
# 96
# 98
# 99
# 100
# 101
# 103
# 104
# 105
# 106
# 108
# 109
# 110
# 111
# 113
# 114
# 115
# 116
# 118
# 119
# 120
# 121
# 123
# 124
# 125
# 126
# 128
# 129
# 130
# 131
# Error
# 133
# 134
# 135
# 136
# 138
# 139
# 140
# 141
# 143
# 144
# 145
# 146
# 148
# 149
# 150
# 151
# 153
# 154
# 155
# 156
# 158
# 159
# 160
# 161
# 163
# 164
# 165
# 166
# 168
# 169
# 170
# 171
# 173
# 174
# 175
# 176
# 178
# 179
# 180
# 181
# 183
# 184
# 185
# 186
# 188
# 189
# 190
# 191
# 193
# 194
# 195
# 196
# 198
# 199
# 200
# Error
# 201
# 203
# 204
# 205
# 206
# 208
# 209
# 210
# 211
# 213
# 214
# 215
# 216
# 218
# 219
# 220
# 221
# 223
# 224
# 225
# 226
# 228
# 229
# 230
# 231
# 233
# 234
# 235
# 236
# 238
# 239
# 240
# 241
# 243
# 244
# 245
# 246
# 248
# 249
# 250
# 251
# 253
# Error
# 254
# 255
# 256
# 258
# 259
# 260
# 261
# 263
# 264
# 265
# 266
# 268
# 269
# 270
# 271
# 273
# 274
# 275
# 276
# 278
# 279
# 280
# 281
# 283
# 284
# 285
# 286
# 288
# 289
# 290
# 291
# Error
# 293
# 294
# 295
# 296
# 298
# 299
# 300
# 301
# 303
# 304
# 305
# 307
# 309
# 310
# 311
# 312
# 314
# 315
# 316
# 317
# 319
# 320
# 321
# 322
# 324
# 325
# 326
# 327
# 329
# 330
# 331
# Error
# 332
# 334
# 335
# 336
# 337
# 339
# 340
# 341
# 342
# 344
# 345
# 346
# 347
# 349
# 350
# 351
# 352
# 354
# 355
# 356
# 357
# 359
# 360
# 361
# 362
# 364
# 365
# 366
# 367
# 369
# 370
# 371
# 372
# 374
# 375
# 376
# 377
# 379
# 380
# 381
# 382
# 384
# 385
# 386
# 387
# 389
# 390
# 391
# 392
# 394
# 395
# 396
# 397
# 399
# 400
# 401
# 402
# 404
# 405
# 406
# 407
# 409
# 410
# 411
# 412
# 414
# 415
# 416
# 417
# 419
# 420
# 421
# 422
# 424
# 425
# 426
# 427
# 429
# 430
# 431
# 432
# 434
# 435
# 436
# 437
# 439
# 440
# 441
# 442
# 444
# 445
# 446
# 447
# 449
# 450
# 451
# 452
# 454
# 455
# 456
# 457
# 459
# 460
# 461
# 462
# 464
# 465
# 466
# 467
# 469
# 470
# 471
# 472
# 474
# 475
# 476
# 477
# 479
# 480
# 481
# 482
# 484
# 485
# 486
# 487
# 489
# 490
# 491
# 492
# 494
# 495
# 496
# 497
# 499
# 500
# 501
# 502
# 504
# 505
# 506
# 507
# 509
# 510
# 511
# 512
# 514
# 515
# 516
# 517
# 519
# 520
# 521
# 522
# 524
# 525
# 526
# 527
# 529
# 530
# 531
# 532
# 534
# 535
# 536
# 537
# 539
# 540
# 541
# 542
# 544
# 545
# 546
# 547
# 549
# 550
# 551
# 552
# 554
# 555
# 556
# 557
# 559
# 560
# 561
# 562
# 564
# 565
# 566
# 567
# 569
# 570
# 571
# 572
# 574
# 575
# 576
# 577
# 579
# 580
# 581
# 582
# 584
# 585
# Error
# 586
# 587
# 589
# 590
# 591
# 592
# 594
# 595
# 596
# 597
# 599
# 600
# 601
# 602
# 604
# 605
# 606
# 607
# 609
# 610
# 611
# 612
# 614
# 615
# 616
# 617
# 619
# 620
# 621
# 622
# 624
# 625
# 626
# 627
# 629
# 630
# 631
# 632
# 634
# 635
# 636
# 637
# 639
# 640
# 641
# 642
# 644
# 645
# 646
# 647
# 649
# 650
# 651
# 652
# 654
# 655
# 656
# 657
# 659
# 660
# 661
# 662
# 664
# 665
# 666
# 667
# 669
# 670
# 671
# 672
# 674
# 675
# 676
# 677
# 679
# 680
# 681
# 682
# 684
# 685
# 686
# 687
# 689
# 690
# 691
# 692
# 694
# 695
# 696
# 697
# 699
# 700
# 701
# 702
# 704
# 705
# 706
# 707
# Error
# 709
# 710
# 711
# 712
# 714
# 715
# 716
# Error
# 717
# 719
# 720
# 721
# 722
# 724
# 725
# 726
# 727
# 729
# 730
# 731
# 732
# 734
# 735
# 736
# 737
# 739
# 740
# 741
# 742
# 744
# 745
# 746
# 747
# Error
# 749
# 750
# 751
# 752
# 754
# 755
# 756
# 757
# 759
# 760
# 761
# 762
# 764
# 765
# 766
# 767
# 769
# 770
# 771
# 772
# 774
# 775
# Error
# 776
# 777
# 779
# 780
# 781
# 782
# 784
# 785
# 786
# 787
# 789
# 790
# 791
# 792
# 794
# 795
# 796
# 797
# 799
# 800
# 801
# 802
# 804
# 805
# 806
# 807
# 809
# 810
# 811
# 812
# 814
# 815
# 816
# 817
# 819
# 820
# 821
# Error
# 822
# 824
# 825
# 826
# 827
# 829
# 830
# 831
# 832
# 834
# Error
# 835
# 836
# 837
# 839
# 840
# 841
# 842
# 844
# 845
# 846
# 847
# 849
# Error
# 850
# 851
# 852
# 854
# 855
# 856
# 857
# 859
# 860
# 861
# 862
# 864
# 865
# 866
# 867
# 869
# 870
# 871
# 872
# 874
# Error
# 875
# 876
# 877
# 879
# 880
# 881
# 882
# 884
# 885
# 886
# 887
# 889
# 890
# 891
# 892
# 894
# 895
# 896
# 897
# 899
# 900
# 901
# 902
# 904
# 905
# 906
# 907
# 909
# 910
# 911
# 912
# 914
# 915
# 916
# 917
# 919
# 920
# 921
# 922
# 924
# 925
# 926
# 927
# 929
# 930
# 931
# 932
# 934
# 935
# 936
# 937
# 939
# 940
# 941
# 942
# 944
# 945
# 946
# 947
# 949
# 950
# 951
# 952
# 954
# 955
# 956
# 957
# 959
# 960
# 961
# 962
# 964
# 965
# 966
# 967
# 969
# 970
# 971
# 972
# 974
# 975
# 976
# 977
# 979
# 980
# 981
# 982
# 984
# 985
# 986
# 987
# 989
# 990
# 991
# 992
# 994
# 995
# 996
# 997
# 999
# 1000
# 1001
# 1002
# 1004
# 1005
# 1006
# 1008
# 1010
# 1011
# 1012
# 1013
# 1015
# 1016
# 1017
# 1018
# 1020
# 1021
# 1022
# 1023
# 1025
# 1026
# 1027
# 1028
# 1030
# 1031
# 1032
# 1033
# 1035
# 1036
# 1037
# 1038
# 1040
# 1041
# 1042
# 1043
# 1045
# 1046
# 1047
# Error
# 1048
# 1050
# 1051
# 1052
# 1053
# 1055
# 1056
# 1057
# 1058
# 1060
# 1061
# 1062
# 1063
# 1065
# 1066
# 1067
# 1068
# 1070
# 1071
# 1072
# 1073
# 1075
# 1076
# 1077
# 1078
# 1080
# 1081
# 1082
# 1083
# 1085
# 1086
# 1087
# 1088
# 1090
# 1091
# 1092
# 1093
# 1095
# 1096
# 1097
# 1098
# 1100
# 1101
# 1102
# 1103
# 1105
# 1106
# 1107
# 1108
# 1110
# 1111
# 1112
# 1113
# 1115
# 1116
# 1117
# 1118
# 1120
# 1121
# 1122
# 1123
# 1125
# 1126
# 1127
# 1128
# 1130
# 1131
# 1132
# 1133
# 1135
# 1136
# 1137
# 1138
# 1140
# 1141
# 1142
# 1143
# 1145
# 1146
# 1147
# 1148
# 1150
# 1151
# 1152
# 1153
# 1155
# 1156
# 1157
# 1158
# 1160
# 1161
# 1162
# 1163
# 1165
# 1166
# 1167
# 1168
# 1170
# 1171
# 1172
# 1173
# 1175
# 1176
# 1177
# 1178
# 1180
# 1181
# 1182
# Error
# 1183
# 1185
# 1186
# 1187
# 1188
# 1190
# 1191
# 1192
# 1193
# 1195
# 1196
# 1197
# 1198
# 1200
# 1201
# 1202
# 1203
# 1205
# 1206
# 1207
# 1208
# 1210
# 1211
# 1212
# 1213
# 1215
# 1216
# 1217
# 1218
# 1220
# 1221
# 1222
# 1223
# 1225
# 1226
# 1227
# 1228
# 1230
# 1231
# 1232
# 1233
# 1235
# 1236
# 1237
# 1238
# 1240
# 1241
# 1242
# 1243
# 1245
# 1246
# 1247
# 1248
# 1250
# 1251
# 1252
# 1253
# 1255
# 1256
# 1257
# 1258
# 1260
# 1261
# 1262
# 1263
# 1265
# 1266
# 1267
# 1268
# 1270
# 1271
# 1272
# 1273
# 1275
# 1276
# 1277
# 1278
# 1280
# 1281
# 1282
# 1283
# 1285
# 1286
# 1287
# 1288
# 1290
# 1291
# 1292
# 1293
# 1295
# 1296
# 1297
# 1298
# 1300
# 1301
# 1302
# 1303
# 1305
# 1306
# 1307
# 1308
# 1310
# 1311
# 1312
# 1313
# 1315
# 1316
# 1317
# 1318
# 1320
# 1321
# 1322
# 1323
# 1325
# 1326
# 1327
# 1328
# 1330
# 1331
# 1332
# 1333
# 1335
# 1336
# 1337
# 1338
# 1340
# 1341
# 1342
# 1343
# 1345
# 1346
# 1347
# 1348
# 1350
# 1351
# 1352
# 1353
# 1355
# 1356
# 1357
# 1358
# 1360
# 1361
# 1362
# 1363
# 1365
# 1366
# 1367
# 1368
# 1370
# 1371
# 1372
# 1373
# 1375
# 1376
# 1377
# 1378
# 1380
# 1381
# 1382
# 1383
# 1385
# 1386
# 1387
# 1388
# 1390
# 1391
# 1392
# 1393
# 1395
# 1396
# 1397
# 1398
# 1400
# 1401
# 1402
# 1403
# 1405
# 1406
# 1407
# 1408
# 1410
# 1411
# 1412
# 1413
# 1415
# 1416
# 1417
# 1418
# 1420
# 1421
# 1422
# 1423
# 1425
# 1426
# 1427
# 1428
# 1430
# 1431
# 1432
# 1433
# 1435
# 1436
# 1437
# 1438
# 1440
# 1441
# 1442
# 1443
# 1445
# 1446
# 1447
# 1448
# 1450
# 1451
# 1452
# 1453
# 1455
# 1456
# 1457
# 1458
# 1460
# 1461
# 1462
# 1463
# 1465
# 1466
# 1467
# 1468
# 1470
# 1471
# 1472
# 1473
# 1475
# 1476
# 1477
# 1478
# 1481
# 1484
# 1485
# 1486
# 1490
# 1491
# 1492
# 1493
# 1495
# 1496
# 1498
# 1499
# 1501
# 1502
# 1503
# 1504
# 1506
# 1507
# 1508
# 1509
# 1511
# 1512
# 1515
# 1517
# Error
# 1520
# 1525
# 1527
# 1530
# 1532
# 1533
# 1534
# 1535
# 1537
# 1538
# 1540
# 1541
# 1543
# 1545
# 1547
# 1548
# 1552
# 1553
# 1555
# 1556
# 1558
# Error
# 1560
# 1561
# 1563
# 1571
# 1572
# 1573
# 1574
# 1581
# 1582
# 1584
# 1585
# 1587
# 1592
# 1593
# 1596
# 1601
# 1603
# 1605
# 1607
# 1609
# 1611
# 1612
# 1613
# 1615
# Error
# 1616
# 1617
# 1618
# 1623
# 1624
# 1625
# 1630
# 1632
# 1634
# 1636
# 1637
# 1641
# 1644
# 1645
# 1646
# 1648
# 1651
# 1653
# 1654
# 1656
# 1658
# 1662
# 1663
# 1667
# 1668
# 1669
# 1671
# 1675
# 1676
# 1678
# 1681
# 1684
# 1687
# 1690
# 1694
# 1698
# 1700
# 1703
# 1707
# 1711
# 1712
# 1713
# Error
# 1715
# 1720
# 1721
# 1722
# 1727
# 1732
# 1733
# 1734
# 1737
# 1740
# 1741
# 1742
# 1743
# 1746
# 1747
# 1748
# 1749
# 1751
# 1752
# 1753
# 1755
# 1757
# 1761
# 1762
# 1764
# 1766
# 1770
# 1771
# 1772
# 1774
# 1775
# 1776
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error

# %%
data_scam.to_csv('partial_scamlist.csv')

# %%
print(errors)
# Out:
# [131, 200, 253, 291, 331, 585, 707, 716, 747, 775, 821, 834, 849, 874, 1047, 1182, 1517, 1558, 1615, 1713, 1777, 1779, 1780, 1781, 1782, 1785, 1786, 1787, 1788, 1790, 1791, 1792, 1793, 1795, 1796, 1797, 1798, 1800, 1801, 1802, 1803, 1805, 1806, 1807, 1809, 1811, 1812, 1813, 1814, 1816, 1817, 1818, 1819, 1821, 1822, 1823, 1824, 1826, 1827, 1828, 1829, 1831, 1832, 1833, 1834, 1836, 1837, 1839, 1840, 1842, 1843, 1845, 1846, 1848, 1849, 1850, 1851, 1853, 1854, 1856, 1857, 1860, 1861, 1862, 1863, 1865, 1866, 1867, 1868, 1870, 1872, 1873, 1874, 1876, 1877, 1878, 1879, 1881, 1882, 1884, 1885, 1893, 1894, 1896, 1897, 1899, 1900, 1901, 1902, 1904, 1905, 1906, 1907, 1911, 1912, 1913, 1914, 1916, 1919, 1921, 1922, 1926, 1927, 1928, 1931, 1934, 1935, 1936, 1937, 1939, 1941, 1942, 1943, 1945, 1946, 1947, 1948, 1950, 1951, 1952, 1954, 1961, 1963, 1965, 1966, 1970, 1973, 1974, 1978, 1982, 1983, 1984, 1985, 1987, 1989, 1991, 1992, 1994, 1995, 1996, 1997, 1999, 2000, 2001, 2002, 2004, 2005, 2006, 2007, 2009, 2010, 2011, 2012, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2024, 2025, 2026, 2027, 2030, 2032, 2033, 2034, 2036, 2037, 2038, 2039, 2041, 2042, 2043, 2044, 2046, 2047, 2048, 2049, 2051, 2052, 2053, 2054, 2056, 2057, 2058, 2059, 2061, 2062, 2063, 2064, 2066, 2067, 2068, 2069, 2071, 2074, 2076, 2077, 2080, 2082, 2084, 2085, 2087, 2088, 2089, 2090, 2092, 2093, 2094, 2095, 2097, 2098, 2099, 2100, 2102, 2103, 2104, 2105, 2107, 2108, 2110, 2113, 2117, 2120, 2123, 2126, 2132]

# %%
ind = errors 
n_iter = 0
ind_errors = []
    
for j in ind_no_corr:
    n_iter += 1 
    if (n_iter%5 != 0):
        try:
                
            url = df.iloc[ind_no_corr[j],].addresses
            source = requests.get("https://www.etherchain.org/account/{}".format(url)).text
            soup = BeautifulSoup(source,'lxml')
            extract_data = soup.find('p',class_="mb-4") 
            string = remove_html_markup(str(extract_data))

            s = str()
            for i in range(len(string)):
                if string[i] != 'E':
                    s+= string[i]
                else:
                    break
            print(j)
            balance = float(s)
       
            balances[j] = balance
# Out:
# 250

# %%
data_scam.iloc[131,]
# Out:
# addresses    0xab1c30cd2d9964b3b845ef744e2e4043739430e5
# precision                        Phishing bitclaive.com
# balance                                               0
# txn                                                   0
# Name: 131, dtype: object

# %%
data_scam.iloc[200,]
# Out:
# addresses    0xb37da5c9179345341fe50d37cfc961ba47c01f9a
# precision                          Phishing gatcoins.io
# balance                                               0
# txn                                                   0
# Name: 200, dtype: object

# %%
https://api.etherscan.io/api?module=account&action=balancemulti&address={}&tag=latest&apikey=YourApiKeyToken

# %%
def parse_all_ethscam2():

    
    # On importe d'abord l'ensemble des données non formatées du site 
    scam_data = get_ethscam_data()
    
    # Indices des adresses scams uniquement liées a l'ETH
    ind = scam_data.iloc[2] == "ETH" 
    ind = np.argwhere(ind)[:,0]
    
    # Création du tableau "propre"
    
    df = pd.DataFrame()
    
    # Récupération des addresses 
    addresses = np.array(scam_data.iloc[:,ind].columns)
    
    # Récupération des descriptifs 
    prec1 = np.array(scam_data.iloc[1,ind])
    prec2 = np.array(scam_data.iloc[6,ind])
    prec = []
    for i,j in zip(prec1,prec2):
        prec.append(i+" "+j)
    
    # On remplit le tableau 
    df['addresses'] = addresses
    df['precision'] = prec
    
    # On retire les adresses non ETH 
    non_eth_ind = np.argwhere([i[0:2] != '0x' for i in df.addresses])[:,0]
    df = df.drop(non_eth_ind)
    
    # On retire les transactions 
    non_addresses = np.argwhere([len(i) > 42 for i in df.addresses])[:,0]
    df = df.drop(non_addresses)
    
    """
    On complète le tableau avec les balances et les transactions 
    https://api.etherscan.io/api?module=account&action=balancemulti&address={}&tag=latest&apikey=B16PQFQJ9UPYNBP8R6YXF3631EVRTBHUFZ
    EXTRACTION DES BALANCES 
    """
    
    urls = []
    n = 1
    url = str()
    n_iters = np.ceil(df.shape[0]/20) # Le nombre de requetes nécessaires, on ne peut en faire que par batch de 20
    compteur = 0
    
    for add in df.addresses:
        if n%20 != 0:
            url = url + add +',' 
            n += 1
            
            
            
            
        else:
            url = url + add 
            urls.append(url)
            url = str()
            n = 1
            compteur += 1 
            
    if compteur != n_iters:
        url = str()
        for add in df.addresses[(compteur*20)+1:]:
            url = url + add +',' 
            
        url = url[:-1]    
        urls.append(url)
    
    
    # adresse de l'api
    URL = "https://api.etherscan.io/api?module=account&action=balancemulti&address={}&tag=latest&apikey=B16PQFQJ9UPYNBP8R6YXF3631EVRTBHUFZ".format(urls[0])
    r = requests.get(url = URL) 
  
    # extraction du json
    data = r.json() 
    
    res = data['result']
    df_res = pd.DataFrame(data=res)
    df_res['balance'] = df_res['balance'].astype(float)*10**(-18)
    
    """
    EXTRACTION DU NOMBRE DE  TXNS
    
    """
    
    
    
    return(data,df_res,df)

# %%
# defining the api-endpoint  
API_ENDPOINT = "https://mainnet.infura.io/v3/c6a6f0e057ec465b90b5b85c5cdb5990"
  

data = {"jsonrpc":"2.0","method":"eth_getTransactionCount","params": ["0xab1c30cd2d9964b3b845ef744e2e4043739430e5","latest"],"id":1}
headers = {"Content-Type": "application/json"}

# sending post request and saving response as response object 
r = requests.post(url = API_ENDPOINT, json = data, headers=headers) 
  
# extracting response text  
pastebin_url = r.text 

dict_res = eval(pastebin_url)
res = dict_res['result']
res = int(res,16)

# %%
data,df_res,df = parse_all_ethscam2()

# %%
data_list = []
for j in df_res.account:
    data_list.append({"jsonrpc":"2.0","method":"eth_getTransactionCount","params": [j,"latest"],"id":1})

# %%
data_list[0]
# Out:
# {'jsonrpc': '2.0',
#  'method': 'eth_getTransactionCount',
#  'params': ['0x2b065809f6ec6df32878bcd26711a0e2bcf59c26', 'latest'],
#  'id': 1}

# %%
data_list[1]
# Out:
# {'jsonrpc': '2.0',
#  'method': 'eth_getTransactionCount',
#  'params': ['0xd0cc2b24980cbcca47ef755da88b220a82291407', 'latest'],
#  'id': 1}

# %%
res_list = []

for j in data_list:
    data = j
    headers = {"Content-Type": "application/json"}
    
    # sending post request and saving response as response object 
    r = requests.post(url = API_ENDPOINT, json = data, headers=headers) 
  
    # extracting response text  
    pastebin_url = r.text 

    dict_res = eval(pastebin_url)
    res = dict_res['result']
    res = int(res,16)
    res_list.append(res)

# %%
len(data_list)
# Out:
# 20
